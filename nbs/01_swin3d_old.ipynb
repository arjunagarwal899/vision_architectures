# %%
# | default_exp swin3d_old

# %% [markdown]
# # Imports

# %%
# | export

import torch
import numpy as np
from torch import nn
from einops import rearrange, repeat

from vision_architectures.swin3d import Swin3DMIM as Swin3DNewMIM
from vision_architectures.swin3d import populate_and_validate_config

# %% [markdown]
# # Architecture

# %% [markdown]
# ### Basic Layers

# %%
# | export


def get_coords_grid(grid_size):
    d, h, w = grid_size

    grid_d = torch.arange(d, dtype=torch.int32)
    grid_h = torch.arange(h, dtype=torch.int32)
    grid_w = torch.arange(w, dtype=torch.int32)

    grid = torch.meshgrid(grid_w, grid_h, grid_d, indexing="ij")
    grid = torch.stack(grid, axis=0)
    # (3, d, h, w)

    return grid

# %%
# | export


class Swin3DMHSA(nn.Module):
    def __init__(self, dim, num_heads, window_size, use_relative_position_bias):
        super().__init__()

        assert dim % num_heads == 0, "dimension must be divisible by number of heads"

        self.dim = dim
        self.num_heads = num_heads
        self.window_size = window_size

        self.per_head_dim = int(dim // num_heads)

        self.W_q = nn.Linear(dim, dim)
        self.W_k = nn.Linear(dim, dim)
        self.W_v = nn.Linear(dim, dim)

        self.proj = nn.Linear(dim, dim)

        # TODO: Add embed_spacing_info functionality
        # TODO: Add dropout everywhere
        # TODO: Combine qkv into one linear layer
        self.use_relative_position_bias = use_relative_position_bias
        if use_relative_position_bias:
            relative_limits = (2 * window_size[0] - 1, 2 * window_size[1] - 1, 2 * window_size[2] - 1)

            self.relative_position_bias_table = nn.Parameter(torch.randn(num_heads, np.prod(relative_limits)))

            coords = get_coords_grid(window_size)
            coords_flatten = rearrange(
                coords, "three_dimensional d h w -> three_dimensional (d h w)", three_dimensional=3
            )
            relative_coords = coords_flatten[:, :, None] - coords_flatten[:, None, :]
            relative_coords = relative_coords.permute(1, 2, 0).contiguous()
            relative_coords[:, :, 0] += window_size[0] - 1
            relative_coords[:, :, 1] += window_size[1] - 1
            relative_coords[:, :, 2] += window_size[2] - 1
            relative_position_index: torch.Tensor = (
                relative_coords[:, :, 0] * relative_limits[1] * relative_limits[2]
                + relative_coords[:, :, 1] * relative_limits[2]
                + relative_coords[:, :, 2]
            )
            self.relative_position_index = relative_position_index.flatten()

    def forward(self, hidden_states: torch.Tensor):
        # hidden_states: (windowed_b, window_size_z window_size_y window_size_x, dim)
        _, num_patches_z, num_patches_y, num_patches_x, _ = hidden_states.shape

        query = rearrange(
            self.W_q(hidden_states),
            "b nz ny nx (num_heads d) -> b num_heads (nz ny nx) d",
            num_heads=self.num_heads,
        )
        key = rearrange(
            self.W_k(hidden_states),
            "b nz ny nx (num_heads d) -> b num_heads (nz ny nx) d",
            num_heads=self.num_heads,
        )
        value = rearrange(
            self.W_v(hidden_states),
            "b nz ny nx (num_heads d) -> b num_heads (nz ny nx) d",
            num_heads=self.num_heads,
        )
        # num_patches = window_size_z window_size_y window_size_x
        # Each is (windowed_b, num_heads, num_patches, per_head_dim)

        attention_scores = query @ rearrange(key, "b num_heads n d -> b num_heads d n")
        attention_scores = attention_scores / (self.per_head_dim**0.5)
        # (windowed_b, num_heads, num_patches, num_patches)

        if self.use_relative_position_bias:
            relative_position_bias = self.relative_position_bias_table[:, self.relative_position_index]
            relative_position_bias = relative_position_bias.reshape(
                1, np.prod(self.window_size), np.prod(self.window_size), -1
            )
            relative_position_bias = relative_position_bias.permute(0, 3, 1, 2).contiguous()
            attention_scores = attention_scores + relative_position_bias

        attention_probs = nn.functional.softmax(attention_scores, dim=-1)
        # (windowed_b, num_heads, num_patches, num_patches)

        context = attention_probs @ value
        # (windowed_b, num_heads, num_patches, per_head_dim)
        context = rearrange(
            context,
            "b num_heads (num_patches_z num_patches_y num_patches_x) d -> "
            "b num_patches_z num_patches_y num_patches_x (num_heads d)",
            num_patches_z=num_patches_z,
            num_patches_y=num_patches_y,
            num_patches_x=num_patches_x,
        )
        # (windowed_b, window_size_z window_size_y window_size_x, dim)

        context = self.proj(context)
        # (windowed_b, window_size_z window_size_y window_size_x, dim)

        return context

# %%
test = Swin3DMHSA(54, 6, (4, 4, 4), True)
display(test)
display(test(torch.randn(2, 4, 4, 4, 54)).shape)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Swin3DMHSA(
#   (W_q): Linear(in_features=54, out_features=54, bias=True)
#   (W_k): Linear(in_features=54, out_features=54, bias=True)
#   (W_v): Linear(in_features=54, out_features=54, bias=True)
#   (proj): Linear(in_features=54, out_features=54, bias=True)
# )
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# torch.Size([2, 4, 4, 4, 54])

# %%
# | export


class Swin3DLayerMLP(nn.Module):
    def __init__(self, dim, intermediate_ratio):
        super().__init__()
        self.dense1 = nn.Linear(dim, dim * intermediate_ratio)
        self.act = nn.GELU()
        self.dense2 = nn.Linear(dim * intermediate_ratio, dim)

    def forward(self, hidden_states: torch.Tensor):
        # hidden_states: (windowed_b, window_size_z window_size_y window_size_x, dim)
        hidden_states = self.dense1(hidden_states)
        hidden_states = self.act(hidden_states)
        hidden_states = self.dense2(hidden_states)
        return hidden_states

# %%
test = Swin3DLayerMLP(64, 256)
display(test)
display(test(torch.randn(2, 4, 4, 4, 64)).shape)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Swin3DLayerMLP(
#   (dense1): Linear(in_features=64, out_features=16384, bias=True)
#   (act): GELU(approximate='none')
#   (dense2): Linear(in_features=16384, out_features=64, bias=True)
# )
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# torch.Size([2, 4, 4, 4, 64])

# %%
# | export


class Swin3DLayer(nn.Module):
    def __init__(self, dim, num_heads, intermediate_ratio, layer_norm_eps, window_size, use_relative_position_bias):
        super().__init__()

        self.window_size = window_size

        self.layernorm_before = nn.LayerNorm(dim, eps=layer_norm_eps)
        self.mhsa = Swin3DMHSA(dim, num_heads, window_size, use_relative_position_bias)
        self.layernorm_after = nn.LayerNorm(dim, eps=layer_norm_eps)
        self.mlp = Swin3DLayerMLP(dim, intermediate_ratio)

    def forward(self, hidden_states: torch.Tensor):
        # hidden_states: (b, num_patches_z, num_patches_y, num_patches_x, dim)
        _, num_patches_z, num_patches_y, num_patches_x, _ = hidden_states.shape

        # Perform windowing
        window_size_z, window_size_y, window_size_x = self.window_size
        num_windows_z, num_windows_y, num_windows_x = (
            num_patches_z // window_size_z,
            num_patches_y // window_size_y,
            num_patches_x // window_size_x,
        )
        hidden_states = rearrange(
            hidden_states,
            "b (num_windows_z window_size_z) (num_windows_y window_size_y) (num_windows_x window_size_x) dim -> "
            "(b num_windows_z num_windows_y num_windows_x) window_size_z window_size_y window_size_x dim ",
            num_windows_z=num_windows_z,
            num_windows_y=num_windows_y,
            num_windows_x=num_windows_x,
            window_size_z=window_size_z,
            window_size_y=window_size_y,
            window_size_x=window_size_x,
        )

        res_connection1 = hidden_states
        # (windowed_b, window_size_z window_size_y window_size_x, dim)

        hidden_states = self.layernorm_before(hidden_states)
        hidden_states = self.mhsa(hidden_states)
        # (windowed_b, window_size_z window_size_y window_size_x, dim)

        res_connection2 = hidden_states + res_connection1
        # (windowed_b, window_size_z window_size_y window_size_x, dim)

        hidden_states = self.layernorm_after(res_connection2)
        hidden_states = self.mlp(hidden_states)
        # (windowed_b, window_size_z window_size_y window_size_x, dim)

        hidden_states = hidden_states + res_connection2
        # (windowed_b, window_size_z window_size_y window_size_x, dim)

        # Undo windowing
        output = rearrange(
            hidden_states,
            "(b num_windows_z num_windows_y num_windows_x) window_size_z window_size_y window_size_x dim -> "
            "b (num_windows_z window_size_z) (num_windows_y window_size_y) (num_windows_x window_size_x) dim",
            num_windows_z=num_windows_z,
            num_windows_y=num_windows_y,
            num_windows_x=num_windows_x,
            window_size_z=window_size_z,
            window_size_y=window_size_y,
            window_size_x=window_size_x,
        )

        return output

# %%
test = Swin3DLayer(64, 4, 256, 1e-6, (4, 4, 4), True)
display(test)
display(test(torch.randn(2, 4, 4, 4, 64)).shape)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Swin3DLayer(
#   (layernorm_before): LayerNorm((64,), eps=1e-06, elementwise_affine=True)
#   (mhsa): Swin3DMHSA(
#     (W_q): Linear(in_features=64, out_features=64, bias=True)
#     (W_k): Linear(in_features=64, out_features=64, bias=True)
#     (W_v): Linear(in_features=64, out_features=64, bias=True)
#     (proj): Linear(in_features=64, out_features=64, bias=True)
#   )
#   (layernorm_after): LayerNorm((64,), eps=1e-06, elementwise_affine=True)
#   (mlp): Swin3DLayerMLP(
#     (dense1): Linear(in_features=64, out_features=16384, bias=True)
#     (act): GELU(approximate='none')
#     (dense2): Linear(in_features=16384, out_features=64, bias=True)
#   )
# )
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# torch.Size([2, 4, 4, 4, 64])

# %% [markdown]
# ### Stage layers

# %%
# | export


class Swin3DBlock(nn.Module):
    def __init__(self, stage_config):
        super().__init__()

        self.stage_config = stage_config
        self.w_layer = Swin3DLayer(
            stage_config["dim"],
            stage_config["num_heads"],
            stage_config["intermediate_ratio"],
            stage_config["layer_norm_eps"],
            stage_config["window_size"],
            stage_config["use_relative_position_bias"],
        )
        self.sw_layer = Swin3DLayer(
            stage_config["dim"],
            stage_config["num_heads"],
            stage_config["intermediate_ratio"],
            stage_config["layer_norm_eps"],
            stage_config["window_size"],
            stage_config["use_relative_position_bias"],
        )

    def forward(self, hidden_states: torch.Tensor):
        # hidden_states: (b, num_patches_z, num_patches_y, num_patches_x, dim)

        layer_outputs = []

        # First layer
        hidden_states = self.w_layer(hidden_states)
        # (b, num_patches_z, num_patches_y, num_patches_x, dim)

        layer_outputs.append(hidden_states)

        # Shift windows
        window_size_z, window_size_y, window_size_x = self.stage_config["window_size"]
        shifts = (window_size_z // 2, window_size_y // 2, window_size_x // 2)
        hidden_states = torch.roll(hidden_states, shifts=shifts, dims=(1, 2, 3))
        # (b, num_patches_z, num_patches_y, num_patches_x, dim)

        # Second layer
        hidden_states = self.sw_layer(hidden_states)
        # (b, num_patches_z, num_patches_y, num_patches_x, dim)

        # Reverse window shift
        shifts = tuple(-shift for shift in shifts)
        hidden_states = torch.roll(hidden_states, shifts=shifts, dims=(1, 2, 3))
        # (b, num_patches_z, num_patches_y, num_patches_x, dim)

        layer_outputs.append(hidden_states)

        return hidden_states, layer_outputs

# %%
test_stage_config = {
    "depth": 4,
    "dim": 64,
    "num_heads": 4,
    "intermediate_ratio": 4,
    "layer_norm_eps": 1e-6,
    "window_size": (4, 4, 4),
    "use_relative_position_bias": True,
}

test = Swin3DBlock(test_stage_config)
display(test)
o = test(torch.randn(2, 4, 4, 4, 64))
display((o[0].shape, (o[1][0].shape, o[1][1].shape)))
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Swin3DBlock(
#   (w_layer): Swin3DLayer(
#     (layernorm_before): LayerNorm((64,), eps=1e-06, elementwise_affine=True)
#     (mhsa): Swin3DMHSA(
#       (W_q): Linear(in_features=64, out_features=64, bias=True)
#       (W_k): Linear(in_features=64, out_features=64, bias=True)
#       (W_v): Linear(in_features=64, out_features=64, bias=True)
#       (proj): Linear(in_features=64, out_features=64, bias=True)
#     )
#     (layernorm_after): LayerNorm((64,), eps=1e-06, elementwise_affine=True)
#     (mlp): Swin3DLayerMLP(
#       (dense1): Linear(in_features=64, out_features=256, bias=True)
#       (act): GELU(approximate='none')
#       (dense2): Linear(in_features=256, out_features=64, bias=True)
#     )
#   )
#   (sw_layer): Swin3DLayer(
#     (layernorm_before): LayerNorm((64,), eps=1e-06, elementwise_affine=True)
#     (mhsa): Swin3DMHSA(
#       (W_q): Linear(in_features=64, out_features=64, bias=True)
#       (W_k): Linear(in_features=64, out_features=64, bias=True)
#       (W_v): Linear(in_features=64, out_features=64, bias=True)
#       (proj): Linear(in_features=64, out_features=64, bias=True)
#     )
#     (layernorm_after): LayerNorm((64,), eps=1e-06, elementwise_affine=True)
#     (mlp): Swin3DLayerMLP(
#       (dense1): Linear(in_features=64, out_features=256, bias=True)
#       (act): GELU(approximate='none')
#       (dense2): Linear(in_features=256, out_features=64, bias=True)
#     )
#   )
# )
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# (torch.Size([2, 4, 4, 4, 64]), (torch.Size([2, 4, 4, 4, 64]), torch.Size([2, 4, 4, 4, 64])))

# %%
# | export


class Swin3DPatchMerging(nn.Module):
    def __init__(self, merge_window_size, dim, out_dim_ratio):
        super().__init__()

        self.merge_window_size = merge_window_size

        in_dim = dim * np.prod(merge_window_size)
        self.layer_norm = nn.LayerNorm(in_dim)
        self.proj = nn.Linear(in_dim, dim * out_dim_ratio)

    def forward(self, hidden_states: torch.Tensor):
        # hidden_states: (b, num_patches_z, num_patches_y, num_patches_x, dim)

        window_size_z, window_size_y, window_size_x = self.merge_window_size

        hidden_states = rearrange(
            hidden_states,
            "b (new_num_patches_z window_size_z) (new_num_patches_y window_size_y) (new_num_patches_x window_size_x) dim -> "
            "b new_num_patches_z new_num_patches_y new_num_patches_x (window_size_z window_size_y window_size_x dim)",
            window_size_z=window_size_z,
            window_size_y=window_size_y,
            window_size_x=window_size_x,
        )

        hidden_states = self.layer_norm(hidden_states)
        hidden_states = self.proj(hidden_states)
        return hidden_states

# %%
test_stage_config = {
    "depth": 4,
    "dim": 64,
    "num_heads": 4,
    "intermediate_size": 256,
    "layer_norm_eps": 1e-6,
    "window_size": (4, 4, 4),
    "use_relative_position_bias": True,
    "patch_merging": {
        "merge_window_size": (2, 2, 2),
        "out_dim_ratio": 3,
    },
}

test = Swin3DPatchMerging(
    test_stage_config["patch_merging"]["merge_window_size"],
    test_stage_config["dim"],
    test_stage_config["patch_merging"]["out_dim_ratio"],
)
display(test)
display(test(torch.randn(2, 4, 4, 4, 64)).shape)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Swin3DPatchMerging(
#   (layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   (proj): Linear(in_features=512, out_features=192, bias=True)
# )
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# torch.Size([2, 2, 2, 2, 192])

# %%
# | export


class Swin3DStage(nn.Module):
    def __init__(self, stage_config):
        super().__init__()

        self.config = stage_config

        self.blocks = nn.ModuleList(
            [Swin3DBlock(stage_config) for _ in range(stage_config["depth"])],
        )

        self.patch_merging = None
        if stage_config["patch_merging"] is not None:
            self.patch_merging = Swin3DPatchMerging(
                stage_config["patch_merging"]["merge_window_size"],
                stage_config["dim"],
                stage_config["patch_merging"]["out_dim_ratio"],
            )

    def forward(self, hidden_states: torch.Tensor):
        # hidden_states: (b, num_patches_z, num_patches_y, num_patches_x, dim)

        layer_outputs = []
        for layer_module in self.blocks:
            hidden_states, _layer_outputs = layer_module(hidden_states)
            # (b, num_patches_z, num_patches_y, num_patches_x, dim)
            layer_outputs.extend(_layer_outputs)

        if self.patch_merging:
            hidden_states = self.patch_merging(hidden_states)
            # (b, new_num_patches_z, new_num_patches_y, new_num_patches_x, new_dim)

        return hidden_states, layer_outputs

# %%
test_stage_config = {
    "depth": 4,
    "dim": 64,
    "num_heads": 4,
    "intermediate_ratio": 4,
    "layer_norm_eps": 1e-6,
    "window_size": (4, 4, 4),
    "use_relative_position_bias": True,
    "patch_merging": {
        "merge_window_size": (2, 2, 2),
        "out_dim_ratio": 3,
    },
}

test = Swin3DStage(test_stage_config)
display(test)
o = test(torch.randn(2, 4, 4, 4, 64))
display((o[0].shape, [x.shape for x in o[1]]))
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Swin3DStage(
#   (blocks): ModuleList(
#     (0-3): 4 x Swin3DBlock(
#       (w_layer): Swin3DLayer(
#         (layernorm_before): LayerNorm((64,), eps=1e-06, elementwise_affine=True)
#         (mhsa): Swin3DMHSA(
#           (W_q): Linear(in_features=64, out_features=64, bias=True)
#           (W_k): Linear(in_features=64, out_features=64, bias=True)
#           (W_v): Linear(in_features=64, out_features=64, bias=True)
#           (proj): Linear(in_features=64, out_features=64, bias=True)
#         )
#         (layernorm_after): LayerNorm((64,), eps=1e-06, elementwise_affine=True)
#         (mlp): Swin3DLayerMLP(
#           (dense1): Linear(in_features=64, out_features=256, bias=True)
#           (act): GELU(approximate='none')
#           (dense2): Linear(in_features=256, out_features=64, bias=True)
#         )
#       )
#       (sw_layer): Swin3DLayer(
#         (layernorm_before): LayerNorm((64,), eps=1e-06, elementwise_affine=True)
#         (mhsa): Swin3DMHSA(
#           (W_q): Linear(in_features=64, out_features=64, bias=True)
#           (W_k): Linear(in_features=64, out_features=64, bias=True)
#           (W_v): Linear(in_features=64, out_features=64, bias=True)
#           (proj): Linear(in_features=64, out_features=64, bias=True)
#         )
#         (layernorm_after): LayerNorm((64,), eps=1e-06, elementwise_affine=True)
#         (mlp): Swin3DLayerMLP(
#           (dense1): Linear(in_features=64, out_features=256, bias=True)
#           (act): GELU(approximate='none')
#           (dense2): Linear(in_features=256, out_features=64, bias=True)
#         )
#       )
#     )
#   )
#   (patch_merging): Swin3DPatchMerging(
#     (layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (proj): Linear(in_features=512, out_features=192, bias=True)
#   )
# )
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# (
#     torch.Size([2, 2, 2, 2, 192]),
#     [
#         torch.Size([2, 4, 4, 4, 64]),
#         torch.Size([2, 4, 4, 4, 64]),
#         torch.Size([2, 4, 4, 4, 64]),
#         torch.Size([2, 4, 4, 4, 64]),
#         torch.Size([2, 4, 4, 4, 64]),
#         torch.Size([2, 4, 4, 4, 64]),
#         torch.Size([2, 4, 4, 4, 64]),
#         torch.Size([2, 4, 4, 4, 64])
#     ]
# )

# %% [markdown]
# ### Encoder

# %%
# | export


class Swin3DEncoder(nn.Module):
    def __init__(self, config):
        super().__init__()

        self.stages = nn.ModuleList([Swin3DStage(stage_config) for stage_config in config["stages"]])

    def forward(self, hidden_states: torch.Tensor):
        # hidden_states: (b, num_patches_z, num_patches_y, num_patches_x, dim)

        stage_outputs, layer_outputs = [], []
        for stage_module in self.stages:
            hidden_states, _layer_outputs = stage_module(hidden_states)
            # (b, new_num_patches_z, new_num_patches_y, new_num_patches_x, dim)

            stage_outputs.append(hidden_states)
            layer_outputs.extend(_layer_outputs)

        return hidden_states, stage_outputs, layer_outputs

# %%
test_config = {"stages": []}
test_config["stages"].append(
    {
        "depth": 2,
        "dim": 32,
        "num_heads": 4,
        "intermediate_ratio": 4,
        "layer_norm_eps": 1e-6,
        "window_size": (4, 4, 4),
        "use_relative_position_bias": False,
        "patch_merging": {
            "merge_window_size": (2, 2, 2),
            "out_dim_ratio": 3,
        },
    }
)
test_config["stages"].append(
    {
        "depth": 6,
        "dim": test_config["stages"][-1]["dim"] * test_config["stages"][-1]["patch_merging"]["out_dim_ratio"],
        "num_heads": 4,
        "intermediate_ratio": 4,
        "layer_norm_eps": 1e-6,
        "window_size": (4, 4, 4),
        "use_relative_position_bias": True,
        "patch_merging": {
            "merge_window_size": (2, 2, 2),
            "out_dim_ratio": 3,
        },
    }
)

test = Swin3DEncoder(test_config)
display(test)
o = test(torch.randn(2, 16, 16, 16, 32))
display((o[0].shape, [x.shape for x in o[1]], [x.shape for x in o[2]]))
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Swin3DEncoder(
#   (stages): ModuleList(
#     (0): Swin3DStage(
#       (blocks): ModuleList(
#         (0-1): 2 x Swin3DBlock(
#           (w_layer): Swin3DLayer(
#             (layernorm_before): LayerNorm((32,), eps=1e-06, elementwise_affine=True)
#             (mhsa): Swin3DMHSA(
#               (W_q): Linear(in_features=32, out_features=32, bias=True)
#               (W_k): Linear(in_features=32, out_features=32, bias=True)
#               (W_v): Linear(in_features=32, out_features=32, bias=True)
#               (proj): Linear(in_features=32, out_features=32, bias=True)
#             )
#             (layernorm_after): LayerNorm((32,), eps=1e-06, elementwise_affine=True)
#             (mlp): Swin3DLayerMLP(
#               (dense1): Linear(in_features=32, out_features=128, bias=True)
#               (act): GELU(approximate='none')
#               (dense2): Linear(in_features=128, out_features=32, bias=True)
#             )
#           )
#           (sw_layer): Swin3DLayer(
#             (layernorm_before): LayerNorm((32,), eps=1e-06, elementwise_affine=True)
#             (mhsa): Swin3DMHSA(
#               (W_q): Linear(in_features=32, out_features=32, bias=True)
#               (W_k): Linear(in_features=32, out_features=32, bias=True)
#               (W_v): Linear(in_features=32, out_features=32, bias=True)
#               (proj): Linear(in_features=32, out_features=32, bias=True)
#             )
#             (layernorm_after): LayerNorm((32,), eps=1e-06, elementwise_affine=True)
#             (mlp): Swin3DLayerMLP(
#               (dense1): Linear(in_features=32, out_features=128, bias=True)
#               (act): GELU(approximate='none')
#               (dense2): Linear(in_features=128, out_features=32, bias=True)
#             )
#           )
#         )
#       )
#       (patch_merging): Swin3DPatchMerging(
#         (layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (proj): Linear(in_features=256, out_features=96, bias=True)
#       )
#     )
#     (1): Swin3DStage(
#       (blocks): ModuleList(
#         (0-5): 6 x Swin3DBlock(
#           (w_layer): Swin3DLayer(
#             (layernorm_before): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (mhsa): Swin3DMHSA(
#               (W_q): Linear(in_features=96, out_features=96, bias=True)
#               (W_k): Linear(in_features=96, out_features=96, bias=True)
#               (W_v): Linear(in_features=96, out_features=96, bias=True)
#               (proj): Linear(in_features=96, out_features=96, bias=True)
#             )
#             (layernorm_after): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (mlp): Swin3DLayerMLP(
#               (dense1): Linear(in_features=96, out_features=384, bias=True)
#               (act): GELU(approximate='none')
#               (dense2): Linear(in_features=384, out_features=96, bias=True)
#             )
#           )
#           (sw_layer): Swin3DLayer(
#             (layernorm_before): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (mhsa): Swin3DMHSA(
#               (W_q): Linear(in_features=96, out_features=96, bias=True)
#               (W_k): Linear(in_features=96, out_features=96, bias=True)
#               (W_v): Linear(in_features=96, out_features=96, bias=True)
#               (proj): Linear(in_features=96, out_features=96, bias=True)
#             )
#             (layernorm_after): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (mlp): Swin3DLayerMLP(
#               (dense1): Linear(in_features=96, out_features=384, bias=True)
#               (act): GELU(approximate='none')
#               (dense2): Linear(in_features=384, out_features=96, bias=True)
#             )
#           )
#         )
#       )
#       (patch_merging): Swin3DPatchMerging(
#         (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (proj): Linear(in_features=768, out_features=288, bias=True)
#       )
#     )
#   )
# )
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# (
#     torch.Size([2, 4, 4, 4, 288]),
#     [torch.Size([2, 8, 8, 8, 96]), torch.Size([2, 4, 4, 4, 288])],
#     [
#         torch.Size([2, 16, 16, 16, 32]),
#         torch.Size([2, 16, 16, 16, 32]),
#         torch.Size([2, 16, 16, 16, 32]),
#         torch.Size([2, 16, 16, 16, 32]),
#         torch.Size([2, 8, 8, 8, 96]),
#         torch.Size([2, 8, 8, 8, 96]),
#         torch.Size([2, 8, 8, 8, 96]),
#         torch.Size([2, 8, 8, 8, 96]),
#         torch.Size([2, 8, 8, 8, 96]),
#         torch.Size([2, 8, 8, 8, 96]),
#         torch.Size([2, 8, 8, 8, 96]),
#         torch.Size([2, 8, 8, 8, 96]),
#         torch.Size([2, 8, 8, 8, 96]),
#         torch.Size([2, 8, 8, 8, 96]),
#         torch.Size([2, 8, 8, 8, 96]),
#         torch.Size([2, 8, 8, 8, 96])
#     ]
# )

# %% [markdown]
# # Embeddings

# %% [markdown]
# ### Patch embeddings

# %%
# | export


class Swin3DPatchEmbeddings(nn.Module):
    def __init__(self, config):
        super().__init__()

        patch_size = config["patch_size"]
        num_channels = config["in_channels"]
        dim = config["stages"][0]["dim"]

        self.patch_embeddings = nn.Conv3d(
            in_channels=num_channels,
            out_channels=dim,
            kernel_size=patch_size,
            stride=patch_size,
        )

    def forward(self, pixel_values: torch.Tensor):
        # pixel_values: (b, c, z, y, x)

        embeddings = self.patch_embeddings(pixel_values)
        # (b, dim, num_patches_z, num_patches_y, num_patches_x)

        return embeddings

# %%
test_config = {
    "patch_size": (1, 8, 8),
    "in_channels": 1,
    "stages": [{"dim": 12}],
}

test = Swin3DPatchEmbeddings(test_config)
display(test)
o = test(torch.randn(2, 1, 32, 512, 512))
display(o.shape)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Swin3DPatchEmbeddings(
#   (patch_embeddings): Conv3d(1, 12, kernel_size=(1, 8, 8), stride=(1, 8, 8))
# )
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# torch.Size([2, 12, 32, 64, 64])

# %% [markdown]
# ### Position embeddings

# %%
# | export


def get_3d_position_embeddings(embedding_size, grid_size, patch_size=(1, 1, 1)):
    if embedding_size % 6 != 0:
        raise ValueError("embed_dim must be divisible by 6")

    grid = get_coords_grid(grid_size)
    # (3, d, h, w)

    grid = rearrange(grid, "x d h w -> x 1 d h w")
    # (3, 1, d, h, w)

    omega = torch.arange(embedding_size // 6, dtype=torch.float32)
    omega /= embedding_size / 6.0
    omega = 1.0 / 10000**omega
    # (d // 6)

    patch_multiplier = torch.Tensor(patch_size) / min(patch_size)

    position_embeddings = []
    for i, grid_subset in enumerate(grid):
        grid_subset = grid_subset.reshape(-1)
        out = torch.einsum("m,d->md", grid_subset, omega)

        emb_sin = torch.sin(out)
        emb_cos = torch.cos(out)

        emb = torch.cat([emb_sin, emb_cos], axis=1) * patch_multiplier[i]
        position_embeddings.append(emb)

    position_embeddings = torch.cat(position_embeddings, axis=1)
    # (embedding_size, d * h * w)
    d, h, w = grid_size
    position_embeddings = rearrange(position_embeddings, "(d h w) e -> 1 e d h w", d=d, h=h, w=w)
    # (1, embedding_size, d, h, w)

    return position_embeddings

# %%
# | export


def embed_spacings_in_position_embeddings(embeddings: torch.Tensor, spacings: torch.Tensor):
    assert spacings.ndim == 2, "Please provide spacing information for each batch element"
    _, embedding_size, _, _, _ = embeddings.shape
    assert embedding_size % 3 == 0, "To embed spacing info, the embedding size must be divisible by 3"
    embeddings = embeddings * repeat(spacings, f"B S -> B (S {int(embedding_size / 3)}) 1 1 1", S=3)

    return embeddings

# %%
# | export


class Swin3DEmbeddings(nn.Module):
    def __init__(self, config):
        super().__init__()

        self.config = config

        dim = config["stages"][0]["dim"]

        self.patch_embeddings = Swin3DPatchEmbeddings(config)
        self.layer_norm = nn.LayerNorm(dim)

        self.absolute_position_embeddings = None
        if config["use_absolute_position_embeddings"]:
            grid_size = (
                config["image_size"][0] // config["patch_size"][0],
                config["image_size"][1] // config["patch_size"][1],
                config["image_size"][2] // config["patch_size"][2],
            )
            if config["learnable_absolute_position_embeddings"]:
                self.absolute_position_embeddings = nn.Parameter(
                    torch.randn(1, dim, grid_size[0], grid_size[1], grid_size[2])
                )
            else:
                self.absolute_position_embeddings = get_3d_position_embeddings(dim, grid_size, config["patch_size"])

    def forward(
        self,
        pixel_values: torch.Tensor,
        spacings: torch.Tensor,
        mask_patches: torch.Tensor = None,
        mask_token: torch.Tensor = None,
    ):
        # pixel_values: (b, c, z, y, x)

        embeddings = self.patch_embeddings(pixel_values)
        # (b, dim, num_patches_z, num_patches_y, num_patches_x)
        embeddings = rearrange(embeddings, "b d nz ny nx -> b nz ny nx d")
        embeddings = self.layer_norm(embeddings)
        embeddings = rearrange(embeddings, "b nz ny nx d -> b d nz ny nx")
        # (b, dim, num_patches_z, num_patches_y, num_patches_x)

        if mask_patches is not None:
            # mask_patches (binary mask): (b, num_patches_z, num_patches_y, num_patches_x)
            # mask_token: (1, dim, 1, 1, 1)
            mask_patches = repeat(mask_patches, "b z y x -> b d z y x", d=embeddings.shape[1])
            embeddings = (embeddings * (1 - mask_patches)) + (mask_patches * mask_token)

        if self.absolute_position_embeddings is not None:
            absolute_position_embeddings = self.absolute_position_embeddings.to(embeddings.device)
            # (1, dim, num_patches_z, num_patches_y, num_patches_x)
            if self.config["embed_spacing_info"]:
                absolute_position_embeddings = embed_spacings_in_position_embeddings(
                    absolute_position_embeddings, spacings
                )
                # (b, dim, num_patches_z, num_patches_y, num_patches_x)

            embeddings = embeddings + absolute_position_embeddings
            # (b, dim, num_patches_z, num_patches_y, num_patches_x)

        return embeddings

# %%
test_config = {
    "patch_size": (1, 8, 8),
    "in_channels": 1,
    "stages": [{"dim": 36}],
    "use_absolute_position_embeddings": True,
    "learnable_absolute_position_embeddings": False,
    "embed_spacing_info": False,
    "image_size": (32, 512, 512),
}

test = Swin3DEmbeddings(test_config)
display(test)
o = test(
    torch.randn(2, 1, 32, 512, 512),
    torch.randn(2, 3),
)
display(o.shape)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Swin3DEmbeddings(
#   (patch_embeddings): Swin3DPatchEmbeddings(
#     (patch_embeddings): Conv3d(1, 36, kernel_size=(1, 8, 8), stride=(1, 8, 8))
#   )
#   (layer_norm): LayerNorm((36,), eps=1e-05, elementwise_affine=True)
# )
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# torch.Size([2, 36, 32, 64, 64])

# %%
e = get_3d_position_embeddings(6, (2, 2, 2), (1, 1, 1))
display(e.shape)

print("Distance of (0, 0, 0) with other coords")
for i in range(2):
    for j in range(2):
        for k in range(2):
            print((i, j, k), np.linalg.norm(e[0, :, 0, 0, 0] - e[0, :, i, j, k]))
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# torch.Size([1, 6, 2, 2, 2])
# Distance of (0, 0, 0) with other coords
# (0, 0, 0) 0.0
# (0, 0, 1) 0.95885104
# (0, 1, 0) 0.95885104
# (0, 1, 1) 1.3560202
# (1, 0, 0) 0.95885104
# (1, 0, 1) 1.3560202
# (1, 1, 0) 1.3560202
# (1, 1, 1) 1.6607786

# %% [markdown]
# # Models

# %%
# | export


class Swin3DModel(nn.Module):
    def __init__(self, config):
        super().__init__()

        self.embeddings = Swin3DEmbeddings(config)
        self.encoder = Swin3DEncoder(config)

    def forward(
        self,
        pixel_values: torch.Tensor,
        spacings: torch.Tensor,
        mask_patches: torch.Tensor = None,
        mask_token: torch.Tensor = None,
    ):
        # pixel_values: (b, c, z, y, x)
        # spacings: (b, 3)
        # mask_patches: (num_patches_z, num_patches_y, num_patches_x)

        embeddings = self.embeddings(pixel_values, spacings, mask_patches, mask_token)
        # (b, dim, num_patches_z, num_patches_y, num_patches_x)

        embeddings = rearrange(embeddings, "b e nz ny nx -> b nz ny nx e")
        # (b, num_patches_z, num_patches_y, num_patches_x, dim)

        stage_outputs = [embeddings]

        encoded, stage_outputs_, layer_outputs = self.encoder(embeddings)
        stage_outputs.extend(stage_outputs_)
        # encoded: (b, new_num_patches_z, new_num_patches_y, new_num_patches_x, dim)
        # stage_outputs, layer_outputs: list of (b, some_num_patches_z, some_num_patches_y, some_num_patches_x, dim)

        encoded = rearrange(encoded, "b nz ny nx d -> b d nz ny nx")
        # (b, dim, new_num_patches_z, new_num_patches_y, new_num_patches_x)

        for i in range(len(stage_outputs)):
            stage_outputs[i] = rearrange(stage_outputs[i], "b nz ny nx d -> b d nz ny nx")
            # (b, dim, some_num_patches_z, some_num_patches_y, some_num_patches_x)

        for i in range(len(layer_outputs)):
            layer_outputs[i] = rearrange(layer_outputs[i], "b nz ny nx d -> b d nz ny nx")
            # (b, dim, some_num_patches_z, some_num_patches_y, some_num_patches_x)

        return encoded, stage_outputs, layer_outputs

# %%
test_config = {
    "patch_size": (1, 8, 8),
    "in_channels": 1,
    "use_absolute_position_embeddings": True,
    "learnable_absolute_position_embeddings": False,
    "embed_spacing_info": False,
    "image_size": (32, 512, 512),
    "stages": [],
}
test_config["stages"].append(
    {
        "depth": 2,
        "dim": 36,
        "num_heads": 4,
        "intermediate_ratio": 4,
        "layer_norm_eps": 1e-6,
        "window_size": (4, 4, 4),
        "use_relative_position_bias": False,
        "patch_merging": {
            "merge_window_size": (2, 2, 2),
            "out_dim_ratio": 3,
        },
    }
)
test_config["stages"].append(
    {
        "depth": 6,
        "dim": test_config["stages"][-1]["dim"] * test_config["stages"][-1]["patch_merging"]["out_dim_ratio"],
        "num_heads": 4,
        "intermediate_ratio": 4,
        "layer_norm_eps": 1e-6,
        "window_size": (4, 4, 4),
        "use_relative_position_bias": True,
        "patch_merging": {
            "merge_window_size": (2, 2, 2),
            "out_dim_ratio": 3,
        },
    }
)

test = Swin3DModel(test_config)
display(test)
o = test(
    torch.randn(2, 1, 32, 512, 512),
    torch.randn(2, 3),
)
display((o[0].shape, [x.shape for x in o[1]], [x.shape for x in o[2]]))
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Swin3DModel(
#   (embeddings): Swin3DEmbeddings(
#     (patch_embeddings): Swin3DPatchEmbeddings(
#       (patch_embeddings): Conv3d(1, 36, kernel_size=(1, 8, 8), stride=(1, 8, 8))
#     )
#     (layer_norm): LayerNorm((36,), eps=1e-05, elementwise_affine=True)
#   )
#   (encoder): Swin3DEncoder(
#     (stages): ModuleList(
#       (0): Swin3DStage(
#         (blocks): ModuleList(
#           (0-1): 2 x Swin3DBlock(
#             (w_layer): Swin3DLayer(
#               (layernorm_before): LayerNorm((36,), eps=1e-06, elementwise_affine=True)
#               (mhsa): Swin3DMHSA(
#                 (W_q): Linear(in_features=36, out_features=36, bias=True)
#                 (W_k): Linear(in_features=36, out_features=36, bias=True)
#                 (W_v): Linear(in_features=36, out_features=36, bias=True)
#                 (proj): Linear(in_features=36, out_features=36, bias=True)
#               )
#               (layernorm_after): LayerNorm((36,), eps=1e-06, elementwise_affine=True)
#               (mlp): Swin3DLayerMLP(
#                 (dense1): Linear(in_features=36, out_features=144, bias=True)
#                 (act): GELU(approximate='none')
#                 (dense2): Linear(in_features=144, out_features=36, bias=True)
#               )
#             )
#             (sw_layer): Swin3DLayer(
#               (layernorm_before): LayerNorm((36,), eps=1e-06, elementwise_affine=True)
#               (mhsa): Swin3DMHSA(
#                 (W_q): Linear(in_features=36, out_features=36, bias=True)
#                 (W_k): Linear(in_features=36, out_features=36, bias=True)
#                 (W_v): Linear(in_features=36, out_features=36, bias=True)
#                 (proj): Linear(in_features=36, out_features=36, bias=True)
#               )
#               (layernorm_after): LayerNorm((36,), eps=1e-06, elementwise_affine=True)
#               (mlp): Swin3DLayerMLP(
#                 (dense1): Linear(in_features=36, out_features=144, bias=True)
#                 (act): GELU(approximate='none')
#                 (dense2): Linear(in_features=144, out_features=36, bias=True)
#               )
#             )
#           )
#         )
#         (patch_merging): Swin3DPatchMerging(
#           (layer_norm): LayerNorm((288,), eps=1e-05, elementwise_affine=True)
#           (proj): Linear(in_features=288, out_features=108, bias=True)
#         )
#       )
#       (1): Swin3DStage(
#         (blocks): ModuleList(
#           (0-5): 6 x Swin3DBlock(
#             (w_layer): Swin3DLayer(
#               (layernorm_before): LayerNorm((108,), eps=1e-06, elementwise_affine=True)
#               (mhsa): Swin3DMHSA(
#                 (W_q): Linear(in_features=108, out_features=108, bias=True)
#                 (W_k): Linear(in_features=108, out_features=108, bias=True)
#                 (W_v): Linear(in_features=108, out_features=108, bias=True)
#                 (proj): Linear(in_features=108, out_features=108, bias=True)
#               )
#               (layernorm_after): LayerNorm((108,), eps=1e-06, elementwise_affine=True)
#               (mlp): Swin3DLayerMLP(
#                 (dense1): Linear(in_features=108, out_features=432, bias=True)
#                 (act): GELU(approximate='none')
#                 (dense2): Linear(in_features=432, out_features=108, bias=True)
#               )
#             )
#             (sw_layer): Swin3DLayer(
#               (layernorm_before): LayerNorm((108,), eps=1e-06, elementwise_affine=True)
#               (mhsa): Swin3DMHSA(
#                 (W_q): Linear(in_features=108, out_features=108, bias=True)
#                 (W_k): Linear(in_features=108, out_features=108, bias=True)
#                 (W_v): Linear(in_features=108, out_features=108, bias=True)
#                 (proj): Linear(in_features=108, out_features=108, bias=True)
#               )
#               (layernorm_after): LayerNorm((108,), eps=1e-06, elementwise_affine=True)
#               (mlp): Swin3DLayerMLP(
#                 (dense1): Linear(in_features=108, out_features=432, bias=True)
#                 (act): GELU(approximate='none')
#                 (dense2): Linear(in_features=432, out_features=108, bias=True)
#               )
#             )
#           )
#         )
#         (patch_merging): Swin3DPatchMerging(
#           (layer_norm): LayerNorm((864,), eps=1e-05, elementwise_affine=True)
#           (proj): Linear(in_features=864, out_features=324, bias=True)
#         )
#       )
#     )
#   )
# )
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# (
#     torch.Size([2, 324, 8, 16, 16]),
#     [
#         torch.Size([2, 36, 32, 64, 64]),
#         torch.Size([2, 108, 16, 32, 32]),
#         torch.Size([2, 324, 8, 16, 16])
#     ],
#     [
#         torch.Size([2, 36, 32, 64, 64]),
#         torch.Size([2, 36, 32, 64, 64]),
#         torch.Size([2, 36, 32, 64, 64]),
#         torch.Size([2, 36, 32, 64, 64]),
#         torch.Size([2, 108, 16, 32, 32]),
#         torch.Size([2, 108, 16, 32, 32]),
#         torch.Size([2, 108, 16, 32, 32]),
#         torch.Size([2, 108, 16, 32, 32]),
#         torch.Size([2, 108, 16, 32, 32]),
#         torch.Size([2, 108, 16, 32, 32]),
#         torch.Size([2, 108, 16, 32, 32]),
#         torch.Size([2, 108, 16, 32, 32]),
#         torch.Size([2, 108, 16, 32, 32]),
#         torch.Size([2, 108, 16, 32, 32]),
#         torch.Size([2, 108, 16, 32, 32]),
#         torch.Size([2, 108, 16, 32, 32])
#     ]
# )

# %% [markdown]
# # For MIM

# %%
# | export


class Swin3DMIMDecoder(nn.Module):
    def __init__(self, config):
        super().__init__()

        self.image_size = config["image_size"]
        self.in_channels = config["in_channels"]

        dim = config["stages"][0]["dim"]
        patch_size = config["patch_size"]
        for stage in config["stages"]:
            if stage["patch_merging"] is not None:
                dim *= stage["patch_merging"]["out_dim_ratio"]
                patch_size = tuple(
                    [patch * window for patch, window in zip(patch_size, stage["patch_merging"]["merge_window_size"])]
                )

        out_dim = np.prod(patch_size) * self.in_channels
        self.final_patch_size = patch_size

        self.decoder = nn.Conv3d(dim, out_dim, kernel_size=1)

    def forward(self, encodings: torch.Tensor):
        # encodings: (b, dim, num_patches_z, num_patches_y, num_patches_x)

        decoded = self.decoder(encodings)
        # (b, new_dim, num_patches_z, num_patches_y, num_patches_x)

        decoded = rearrange(
            decoded,
            "b (c pz py px) nz ny nx -> b c (nz pz) (ny py) (nx px)",
            c=self.in_channels,
            pz=self.final_patch_size[0],
            py=self.final_patch_size[1],
            px=self.final_patch_size[2],
        )
        # (b, c, z, y, x)

        return decoded

# %%
test_config = {
    "patch_size": (1, 8, 8),
    "in_channels": 1,
    "use_absolute_position_embeddings": True,
    "learnable_absolute_position_embeddings": False,
    "embed_spacing_info": False,
    "image_size": (32, 512, 512),
    "stages": [],
}
test_config["stages"].append(
    {
        "depth": 2,
        "dim": 36,
        "num_heads": 4,
        "intermediate_ratio": 4,
        "layer_norm_eps": 1e-6,
        "window_size": (4, 4, 4),
        "use_relative_position_bias": False,
        "patch_merging": {
            "merge_window_size": (2, 2, 2),
            "out_dim_ratio": 3,
        },
    }
)
test_config["stages"].append(
    {
        "depth": 6,
        "dim": test_config["stages"][-1]["dim"] * test_config["stages"][-1]["patch_merging"]["out_dim_ratio"],
        "num_heads": 4,
        "intermediate_ratio": 4,
        "layer_norm_eps": 1e-6,
        "window_size": (4, 4, 4),
        "use_relative_position_bias": True,
        "patch_merging": {
            "merge_window_size": (2, 2, 2),
            "out_dim_ratio": 3,
        },
    }
)

test = Swin3DMIMDecoder(test_config)
display(test)
display(test(torch.randn(2, 324, 8, 16, 16)).shape)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Swin3DMIMDecoder(
#   (decoder): Conv3d(324, 4096, kernel_size=(1, 1, 1), stride=(1, 1, 1))
# )
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# torch.Size([2, 1, 32, 512, 512])

# %%
# | export


class Swin3DMIM(nn.Module):
    def __init__(self, config):
        super().__init__()

        self.config = config

        self.swin = Swin3DModel(config)
        self.decoder = Swin3DMIMDecoder(config)

        self.mask_token = nn.Parameter(torch.randn(1, config["stages"][0]["dim"], 1, 1, 1))

    def forward(self, pixel_values: torch.Tensor, spacings: torch.Tensor):
        b = pixel_values.shape[0]

        mask_ratio = self.config["mim"]["mask_ratio"]
        mask_grid_size = self.config["mim"]["mask_grid_size"]
        num_patches = np.prod(mask_grid_size)
        mask_patches = []
        for _ in range(b):
            _mask_patches = torch.zeros(num_patches, dtype=torch.int8, device=pixel_values.device)
            _mask_patches[: int(mask_ratio * num_patches)] = 1
            _mask_patches = _mask_patches[torch.randperm(num_patches)]
            _mask_patches = rearrange(
                _mask_patches, "(z y x) -> z y x", z=mask_grid_size[0], y=mask_grid_size[1], x=mask_grid_size[2]
            )
            mask_patches.append(_mask_patches)
        mask_patches: torch.Tensor = torch.stack(mask_patches, dim=0)

        grid_size = tuple([size // patch for size, patch in zip(self.config["image_size"], self.config["patch_size"])])
        assert all(
            [x % y == 0 for x, y in zip(grid_size, mask_grid_size)]
        ), "Mask grid size must divide image grid size"
        mask_patches = repeat(
            mask_patches,
            "b z y x -> b (z gz) (y gy) (x gx)",
            gz=grid_size[0] // mask_grid_size[0],
            gy=grid_size[1] // mask_grid_size[1],
            gx=grid_size[2] // mask_grid_size[2],
        )

        encodings, _, _ = self.swin(pixel_values, spacings, mask_patches, self.mask_token)

        decoded = self.decoder(encodings)

        loss = nn.functional.l1_loss(decoded, pixel_values, reduction="none")
        mask = repeat(
            mask_patches,
            "b z y x -> b (z pz) (y py) (x px)",
            pz=self.config["patch_size"][0],
            py=self.config["patch_size"][1],
            px=self.config["patch_size"][2],
        )
        loss = (loss * mask).sum() / ((mask.sum() + 1e-5) * self.config["in_channels"])

        return decoded, loss, mask

# %%
test_config = {
    "patch_size": (1, 8, 8),
    "in_channels": 1,
    "use_absolute_position_embeddings": True,
    "learnable_absolute_position_embeddings": False,
    "embed_spacing_info": False,
    "image_size": (32, 512, 512),
    "stages": [],
    "mim": {
        "mask_ratio": 0.8,
        "mask_grid_size": (8, 8, 8),
    },
}
test_config["stages"].append(
    {
        "depth": 2,
        "dim": 36,
        "num_heads": 4,
        "intermediate_ratio": 4,
        "layer_norm_eps": 1e-6,
        "window_size": (4, 4, 4),
        "use_relative_position_bias": False,
        "patch_merging": {
            "merge_window_size": (2, 2, 2),
            "out_dim_ratio": 3,
        },
    }
)
test_config["stages"].append(
    {
        "depth": 6,
        "dim": test_config["stages"][-1]["dim"] * test_config["stages"][-1]["patch_merging"]["out_dim_ratio"],
        "num_heads": 4,
        "intermediate_ratio": 4,
        "layer_norm_eps": 1e-6,
        "window_size": (4, 4, 4),
        "use_relative_position_bias": True,
        "patch_merging": {
            "merge_window_size": (2, 2, 2),
            "out_dim_ratio": 3,
        },
    }
)

test = Swin3DMIM(test_config)
display(test)
o = test(
    torch.randn(2, 1, 32, 512, 512),
    torch.randn(2, 3),
)
display((o[0].shape, o[1], o[2].shape))
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Swin3DMIM(
#   (swin): Swin3DModel(
#     (embeddings): Swin3DEmbeddings(
#       (patch_embeddings): Swin3DPatchEmbeddings(
#         (patch_embeddings): Conv3d(1, 36, kernel_size=(1, 8, 8), stride=(1, 8, 8))
#       )
#       (layer_norm): LayerNorm((36,), eps=1e-05, elementwise_affine=True)
#     )
#     (encoder): Swin3DEncoder(
#       (stages): ModuleList(
#         (0): Swin3DStage(
#           (blocks): ModuleList(
#             (0-1): 2 x Swin3DBlock(
#               (w_layer): Swin3DLayer(
#                 (layernorm_before): LayerNorm((36,), eps=1e-06, elementwise_affine=True)
#                 (mhsa): Swin3DMHSA(
#                   (W_q): Linear(in_features=36, out_features=36, bias=True)
#                   (W_k): Linear(in_features=36, out_features=36, bias=True)
#                   (W_v): Linear(in_features=36, out_features=36, bias=True)
#                   (proj): Linear(in_features=36, out_features=36, bias=True)
#                 )
#                 (layernorm_after): LayerNorm((36,), eps=1e-06, elementwise_affine=True)
#                 (mlp): Swin3DLayerMLP(
#                   (dense1): Linear(in_features=36, out_features=144, bias=True)
#                   (act): GELU(approximate='none')
#                   (dense2): Linear(in_features=144, out_features=36, bias=True)
#                 )
#               )
#               (sw_layer): Swin3DLayer(
#                 (layernorm_before): LayerNorm((36,), eps=1e-06, elementwise_affine=True)
#                 (mhsa): Swin3DMHSA(
#                   (W_q): Linear(in_features=36, out_features=36, bias=True)
#                   (W_k): Linear(in_features=36, out_features=36, bias=True)
#                   (W_v): Linear(in_features=36, out_features=36, bias=True)
#                   (proj): Linear(in_features=36, out_features=36, bias=True)
#                 )
#                 (layernorm_after): LayerNorm((36,), eps=1e-06, elementwise_affine=True)
#                 (mlp): Swin3DLayerMLP(
#                   (dense1): Linear(in_features=36, out_features=144, bias=True)
#                   (act): GELU(approximate='none')
#                   (dense2): Linear(in_features=144, out_features=36, bias=True)
#                 )
#               )
#             )
#           )
#           (patch_merging): Swin3DPatchMerging(
#             (layer_norm): LayerNorm((288,), eps=1e-05, elementwise_affine=True)
#             (proj): Linear(in_features=288, out_features=108, bias=True)
#           )
#         )
#         (1): Swin3DStage(
#           (blocks): ModuleList(
#             (0-5): 6 x Swin3DBlock(
#               (w_layer): Swin3DLayer(
#                 (layernorm_before): LayerNorm((108,), eps=1e-06, elementwise_affine=True)
#                 (mhsa): Swin3DMHSA(
#                   (W_q): Linear(in_features=108, out_features=108, bias=True)
#                   (W_k): Linear(in_features=108, out_features=108, bias=True)
#                   (W_v): Linear(in_features=108, out_features=108, bias=True)
#                   (proj): Linear(in_features=108, out_features=108, bias=True)
#                 )
#                 (layernorm_after): LayerNorm((108,), eps=1e-06, elementwise_affine=True)
#                 (mlp): Swin3DLayerMLP(
#                   (dense1): Linear(in_features=108, out_features=432, bias=True)
#                   (act): GELU(approximate='none')
#                   (dense2): Linear(in_features=432, out_features=108, bias=True)
#                 )
#               )
#               (sw_layer): Swin3DLayer(
#                 (layernorm_before): LayerNorm((108,), eps=1e-06, elementwise_affine=True)
#                 (mhsa): Swin3DMHSA(
#                   (W_q): Linear(in_features=108, out_features=108, bias=True)
#                   (W_k): Linear(in_features=108, out_features=108, bias=True)
#                   (W_v): Linear(in_features=108, out_features=108, bias=True)
#                   (proj): Linear(in_features=108, out_features=108, bias=True)
#                 )
#                 (layernorm_after): LayerNorm((108,), eps=1e-06, elementwise_affine=True)
#                 (mlp): Swin3DLayerMLP(
#                   (dense1): Linear(in_features=108, out_features=432, bias=True)
#                   (act): GELU(approximate='none')
#                   (dense2): Linear(in_features=432, out_features=108, bias=True)
#                 )
#               )
#             )
#           )
#           (patch_merging): Swin3DPatchMerging(
#             (layer_norm): LayerNorm((864,), eps=1e-05, elementwise_affine=True)
#             (proj): Linear(in_features=864, out_features=324, bias=True)
#           )
#         )
#       )
#     )
#   )
#   (decoder): Swin3DMIMDecoder(
#     (decoder): Conv3d(324, 4096, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#   )
# )
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# (
#     torch.Size([2, 1, 32, 512, 512]),
#     tensor(1.6864, grad_fn=<DivBackward0>),
#     torch.Size([2, 32, 512, 512])
# )

# %%
from neuro_utils.visualize import plot_scans

plot_scans([o[0][0, 0].detach(), o[0][0, 0].detach() * (1 - o[2][0])])
# Out:
# interactive(children=(IntSlider(value=0, description='z', max=31), Output()), _dom_classes=('widget-interact',…

# %% [markdown]
# # Some more tests

# %%
test_config = {
    "patch_size": (1, 8, 8),
    "in_channels": 1,
    "use_absolute_position_embeddings": True,
    "learnable_absolute_position_embeddings": False,
    "embed_spacing_info": False,
    "image_size": (32, 512, 512),
    "stages": [],
    "mask_ratio": 0.8,
}
test_config["stages"].append(
    {
        "depth": 1,
        "dim": 48,
        "num_heads": 4,
        "intermediate_ratio": 4,
        "layer_norm_eps": 1e-6,
        "window_size": (4, 4, 4),
        "use_relative_position_bias": False,
        "patch_merging": {
            "merge_window_size": (2, 2, 2),
            "out_dim_ratio": 2,
        },
    }
)
test_config["stages"].append(
    {
        "depth": 1,
        "dim": test_config["stages"][-1]["dim"] * test_config["stages"][-1]["patch_merging"]["out_dim_ratio"],
        "num_heads": 4,
        "intermediate_ratio": 4,
        "layer_norm_eps": 1e-6,
        "window_size": (4, 4, 4),
        "use_relative_position_bias": False,
        "patch_merging": {
            "merge_window_size": (2, 2, 2),
            "out_dim_ratio": 2,
        },
    }
)
test_config["stages"].append(
    {
        "depth": 3,
        "dim": test_config["stages"][-1]["dim"] * test_config["stages"][-1]["patch_merging"]["out_dim_ratio"],
        "num_heads": 4,
        "intermediate_ratio": 4,
        "layer_norm_eps": 1e-6,
        "window_size": (4, 4, 4),
        "use_relative_position_bias": False,
        "patch_merging": {
            "merge_window_size": (2, 2, 2),
            "out_dim_ratio": 2,
        },
    }
)
test_config["stages"].append(
    {
        "depth": 1,
        "dim": test_config["stages"][-1]["dim"] * test_config["stages"][-1]["patch_merging"]["out_dim_ratio"],
        "num_heads": 4,
        "intermediate_ratio": 4,
        "layer_norm_eps": 1e-6,
        "window_size": (4, 4, 4),
        "use_relative_position_bias": True,
        "patch_merging": None,
    }
)

test = Swin3DModel(test_config)
display(test)
o = test(
    torch.randn(2, 1, 32, 512, 512),
    torch.randn(2, 3),
)
display((o[0].shape, [x.shape for x in o[1]], [x.shape for x in o[2]]))
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Swin3DModel(
#   (embeddings): Swin3DEmbeddings(
#     (patch_embeddings): Swin3DPatchEmbeddings(
#       (patch_embeddings): Conv3d(1, 48, kernel_size=(1, 8, 8), stride=(1, 8, 8))
#     )
#     (layer_norm): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#   )
#   (encoder): Swin3DEncoder(
#     (stages): ModuleList(
#       (0): Swin3DStage(
#         (blocks): ModuleList(
#           (0): Swin3DBlock(
#             (w_layer): Swin3DLayer(
#               (layernorm_before): LayerNorm((48,), eps=1e-06, elementwise_affine=True)
#               (mhsa): Swin3DMHSA(
#                 (W_q): Linear(in_features=48, out_features=48, bias=True)
#                 (W_k): Linear(in_features=48, out_features=48, bias=True)
#                 (W_v): Linear(in_features=48, out_features=48, bias=True)
#                 (proj): Linear(in_features=48, out_features=48, bias=True)
#               )
#               (layernorm_after): LayerNorm((48,), eps=1e-06, elementwise_affine=True)
#               (mlp): Swin3DLayerMLP(
#                 (dense1): Linear(in_features=48, out_features=192, bias=True)
#                 (act): GELU(approximate='none')
#                 (dense2): Linear(in_features=192, out_features=48, bias=True)
#               )
#             )
#             (sw_layer): Swin3DLayer(
#               (layernorm_before): LayerNorm((48,), eps=1e-06, elementwise_affine=True)
#               (mhsa): Swin3DMHSA(
#                 (W_q): Linear(in_features=48, out_features=48, bias=True)
#                 (W_k): Linear(in_features=48, out_features=48, bias=True)
#                 (W_v): Linear(in_features=48, out_features=48, bias=True)
#                 (proj): Linear(in_features=48, out_features=48, bias=True)
#               )
#               (layernorm_after): LayerNorm((48,), eps=1e-06, elementwise_affine=True)
#               (mlp): Swin3DLayerMLP(
#                 (dense1): Linear(in_features=48, out_features=192, bias=True)
#                 (act): GELU(approximate='none')
#                 (dense2): Linear(in_features=192, out_features=48, bias=True)
#               )
#             )
#           )
#         )
#         (patch_merging): Swin3DPatchMerging(
#           (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           (proj): Linear(in_features=384, out_features=96, bias=True)
#         )
#       )
#       (1): Swin3DStage(
#         (blocks): ModuleList(
#           (0): Swin3DBlock(
#             (w_layer): Swin3DLayer(
#               (layernorm_before): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#               (mhsa): Swin3DMHSA(
#                 (W_q): Linear(in_features=96, out_features=96, bias=True)
#                 (W_k): Linear(in_features=96, out_features=96, bias=True)
#                 (W_v): Linear(in_features=96, out_features=96, bias=True)
#                 (proj): Linear(in_features=96, out_features=96, bias=True)
#               )
#               (layernorm_after): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#               (mlp): Swin3DLayerMLP(
#                 (dense1): Linear(in_features=96, out_features=384, bias=True)
#                 (act): GELU(approximate='none')
#                 (dense2): Linear(in_features=384, out_features=96, bias=True)
#               )
#             )
#             (sw_layer): Swin3DLayer(
#               (layernorm_before): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#               (mhsa): Swin3DMHSA(
#                 (W_q): Linear(in_features=96, out_features=96, bias=True)
#                 (W_k): Linear(in_features=96, out_features=96, bias=True)
#                 (W_v): Linear(in_features=96, out_features=96, bias=True)
#                 (proj): Linear(in_features=96, out_features=96, bias=True)
#               )
#               (layernorm_after): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#               (mlp): Swin3DLayerMLP(
#                 (dense1): Linear(in_features=96, out_features=384, bias=True)
#                 (act): GELU(approximate='none')
#                 (dense2): Linear(in_features=384, out_features=96, bias=True)
#               )
#             )
#           )
#         )
#         (patch_merging): Swin3DPatchMerging(
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (proj): Linear(in_features=768, out_features=192, bias=True)
#         )
#       )
#       (2): Swin3DStage(
#         (blocks): ModuleList(
#           (0-2): 3 x Swin3DBlock(
#             (w_layer): Swin3DLayer(
#               (layernorm_before): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#               (mhsa): Swin3DMHSA(
#                 (W_q): Linear(in_features=192, out_features=192, bias=True)
#                 (W_k): Linear(in_features=192, out_features=192, bias=True)
#                 (W_v): Linear(in_features=192, out_features=192, bias=True)
#                 (proj): Linear(in_features=192, out_features=192, bias=True)
#               )
#               (layernorm_after): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#               (mlp): Swin3DLayerMLP(
#                 (dense1): Linear(in_features=192, out_features=768, bias=True)
#                 (act): GELU(approximate='none')
#                 (dense2): Linear(in_features=768, out_features=192, bias=True)
#               )
#             )
#             (sw_layer): Swin3DLayer(
#               (layernorm_before): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#               (mhsa): Swin3DMHSA(
#                 (W_q): Linear(in_features=192, out_features=192, bias=True)
#                 (W_k): Linear(in_features=192, out_features=192, bias=True)
#                 (W_v): Linear(in_features=192, out_features=192, bias=True)
#                 (proj): Linear(in_features=192, out_features=192, bias=True)
#               )
#               (layernorm_after): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#               (mlp): Swin3DLayerMLP(
#                 (dense1): Linear(in_features=192, out_features=768, bias=True)
#                 (act): GELU(approximate='none')
#                 (dense2): Linear(in_features=768, out_features=192, bias=True)
#               )
#             )
#           )
#         )
#         (patch_merging): Swin3DPatchMerging(
#           (layer_norm): LayerNorm((1536,), eps=1e-05, elementwise_affine=True)
#           (proj): Linear(in_features=1536, out_features=384, bias=True)
#         )
#       )
#       (3): Swin3DStage(
#         (blocks): ModuleList(
#           (0): Swin3DBlock(
#             (w_layer): Swin3DLayer(
#               (layernorm_before): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#               (mhsa): Swin3DMHSA(
#                 (W_q): Linear(in_features=384, out_features=384, bias=True)
#                 (W_k): Linear(in_features=384, out_features=384, bias=True)
#                 (W_v): Linear(in_features=384, out_features=384, bias=True)
#                 (proj): Linear(in_features=384, out_features=384, bias=True)
#               )
#               (layernorm_after): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#               (mlp): Swin3DLayerMLP(
#                 (dense1): Linear(in_features=384, out_features=1536, bias=True)
#                 (act): GELU(approximate='none')
#                 (dense2): Linear(in_features=1536, out_features=384, bias=True)
#               )
#             )
#             (sw_layer): Swin3DLayer(
#               (layernorm_before): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#               (mhsa): Swin3DMHSA(
#                 (W_q): Linear(in_features=384, out_features=384, bias=True)
#                 (W_k): Linear(in_features=384, out_features=384, bias=True)
#                 (W_v): Linear(in_features=384, out_features=384, bias=True)
#                 (proj): Linear(in_features=384, out_features=384, bias=True)
#               )
#               (layernorm_after): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#               (mlp): Swin3DLayerMLP(
#                 (dense1): Linear(in_features=384, out_features=1536, bias=True)
#                 (act): GELU(approximate='none')
#                 (dense2): Linear(in_features=1536, out_features=384, bias=True)
#               )
#             )
#           )
#         )
#       )
#     )
#   )
# )
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# (
#     torch.Size([2, 384, 4, 8, 8]),
#     [
#         torch.Size([2, 48, 32, 64, 64]),
#         torch.Size([2, 96, 16, 32, 32]),
#         torch.Size([2, 192, 8, 16, 16]),
#         torch.Size([2, 384, 4, 8, 8]),
#         torch.Size([2, 384, 4, 8, 8])
#     ],
#     [
#         torch.Size([2, 48, 32, 64, 64]),
#         torch.Size([2, 48, 32, 64, 64]),
#         torch.Size([2, 96, 16, 32, 32]),
#         torch.Size([2, 96, 16, 32, 32]),
#         torch.Size([2, 192, 8, 16, 16]),
#         torch.Size([2, 192, 8, 16, 16]),
#         torch.Size([2, 192, 8, 16, 16]),
#         torch.Size([2, 192, 8, 16, 16]),
#         torch.Size([2, 192, 8, 16, 16]),
#         torch.Size([2, 192, 8, 16, 16]),
#         torch.Size([2, 384, 4, 8, 8]),
#         torch.Size([2, 384, 4, 8, 8])
#     ]
# )

# %%
from neuro_utils.describe import describe_model

describe_model(test)
# Out:
# /home/users/arjun.agarwal/miniconda3/lib/python3.9/site-packages/pydantic/_internal/_config.py:269: UserWarning: Valid config keys have changed in V2:
# * 'smart_union' has been removed
#   warnings.warn(message, UserWarning)
# Total Parameters: 7,284,488
# +----------------------------------------------------------------------+------------+
# |                                Module                                | Parameters |
# +----------------------------------------------------------------------+------------+
# |         embeddings.patch_embeddings.patch_embeddings.weight          |   3,072    |
# |          embeddings.patch_embeddings.patch_embeddings.bias           |     48     |
# |                     embeddings.layer_norm.weight                     |     48     |
# |                      embeddings.layer_norm.bias                      |     48     |
# |      encoder.stages.0.blocks.0.w_layer.layernorm_before.weight       |     48     |
# |       encoder.stages.0.blocks.0.w_layer.layernorm_before.bias        |     48     |
# |          encoder.stages.0.blocks.0.w_layer.mhsa.W_q.weight           |   2,304    |
# |           encoder.stages.0.blocks.0.w_layer.mhsa.W_q.bias            |     48     |
# |          encoder.stages.0.blocks.0.w_layer.mhsa.W_k.weight           |   2,304    |
# |           encoder.stages.0.blocks.0.w_layer.mhsa.W_k.bias            |     48     |
# |          encoder.stages.0.blocks.0.w_layer.mhsa.W_v.weight           |   2,304    |
# |           encoder.stages.0.blocks.0.w_layer.mhsa.W_v.bias            |     48     |
# |          encoder.stages.0.blocks.0.w_layer.mhsa.proj.weight          |   2,304    |
# |           encoder.stages.0.blocks.0.w_layer.mhsa.proj.bias           |     48     |
# |       encoder.stages.0.blocks.0.w_layer.layernorm_after.weight       |     48     |
# |        encoder.stages.0.blocks.0.w_layer.layernorm_after.bias        |     48     |
# |         encoder.stages.0.blocks.0.w_layer.mlp.dense1.weight          |   9,216    |
# |          encoder.stages.0.blocks.0.w_layer.mlp.dense1.bias           |    192     |
# |         encoder.stages.0.blocks.0.w_layer.mlp.dense2.weight          |   9,216    |
# |          encoder.stages.0.blocks.0.w_layer.mlp.dense2.bias           |     48     |
# |      encoder.stages.0.blocks.0.sw_layer.layernorm_before.weight      |     48     |
# |       encoder.stages.0.blocks.0.sw_layer.layernorm_before.bias       |     48     |
# |          encoder.stages.0.blocks.0.sw_layer.mhsa.W_q.weight          |   2,304    |
# |           encoder.stages.0.blocks.0.sw_layer.mhsa.W_q.bias           |     48     |
# |          encoder.stages.0.blocks.0.sw_layer.mhsa.W_k.weight          |   2,304    |
# |           encoder.stages.0.blocks.0.sw_layer.mhsa.W_k.bias           |     48     |
# |          encoder.stages.0.blocks.0.sw_layer.mhsa.W_v.weight          |   2,304    |
# |           encoder.stages.0.blocks.0.sw_layer.mhsa.W_v.bias           |     48     |
# |         encoder.stages.0.blocks.0.sw_layer.mhsa.proj.weight          |   2,304    |
# |          encoder.stages.0.blocks.0.sw_layer.mhsa.proj.bias           |     48     |
# |      encoder.stages.0.blocks.0.sw_layer.layernorm_after.weight       |     48     |
# |       encoder.stages.0.blocks.0.sw_layer.layernorm_after.bias        |     48     |
# |         encoder.stages.0.blocks.0.sw_layer.mlp.dense1.weight         |   9,216    |
# |          encoder.stages.0.blocks.0.sw_layer.mlp.dense1.bias          |    192     |
# |         encoder.stages.0.blocks.0.sw_layer.mlp.dense2.weight         |   9,216    |
# |          encoder.stages.0.blocks.0.sw_layer.mlp.dense2.bias          |     48     |
# |           encoder.stages.0.patch_merging.layer_norm.weight           |    384     |
# |            encoder.stages.0.patch_merging.layer_norm.bias            |    384     |
# |              encoder.stages.0.patch_merging.proj.weight              |   36,864   |
# |               encoder.stages.0.patch_merging.proj.bias               |     96     |
# |      encoder.stages.1.blocks.0.w_layer.layernorm_before.weight       |     96     |
# |       encoder.stages.1.blocks.0.w_layer.layernorm_before.bias        |     96     |
# |          encoder.stages.1.blocks.0.w_layer.mhsa.W_q.weight           |   9,216    |
# |           encoder.stages.1.blocks.0.w_layer.mhsa.W_q.bias            |     96     |
# |          encoder.stages.1.blocks.0.w_layer.mhsa.W_k.weight           |   9,216    |
# |           encoder.stages.1.blocks.0.w_layer.mhsa.W_k.bias            |     96     |
# |          encoder.stages.1.blocks.0.w_layer.mhsa.W_v.weight           |   9,216    |
# |           encoder.stages.1.blocks.0.w_layer.mhsa.W_v.bias            |     96     |
# |          encoder.stages.1.blocks.0.w_layer.mhsa.proj.weight          |   9,216    |
# |           encoder.stages.1.blocks.0.w_layer.mhsa.proj.bias           |     96     |
# |       encoder.stages.1.blocks.0.w_layer.layernorm_after.weight       |     96     |
# |        encoder.stages.1.blocks.0.w_layer.layernorm_after.bias        |     96     |
# |         encoder.stages.1.blocks.0.w_layer.mlp.dense1.weight          |   36,864   |
# |          encoder.stages.1.blocks.0.w_layer.mlp.dense1.bias           |    384     |
# |         encoder.stages.1.blocks.0.w_layer.mlp.dense2.weight          |   36,864   |
# |          encoder.stages.1.blocks.0.w_layer.mlp.dense2.bias           |     96     |
# |      encoder.stages.1.blocks.0.sw_layer.layernorm_before.weight      |     96     |
# |       encoder.stages.1.blocks.0.sw_layer.layernorm_before.bias       |     96     |
# |          encoder.stages.1.blocks.0.sw_layer.mhsa.W_q.weight          |   9,216    |
# |           encoder.stages.1.blocks.0.sw_layer.mhsa.W_q.bias           |     96     |
# |          encoder.stages.1.blocks.0.sw_layer.mhsa.W_k.weight          |   9,216    |
# |           encoder.stages.1.blocks.0.sw_layer.mhsa.W_k.bias           |     96     |
# |          encoder.stages.1.blocks.0.sw_layer.mhsa.W_v.weight          |   9,216    |
# |           encoder.stages.1.blocks.0.sw_layer.mhsa.W_v.bias           |     96     |
# |         encoder.stages.1.blocks.0.sw_layer.mhsa.proj.weight          |   9,216    |
# |          encoder.stages.1.blocks.0.sw_layer.mhsa.proj.bias           |     96     |
# |      encoder.stages.1.blocks.0.sw_layer.layernorm_after.weight       |     96     |
# |       encoder.stages.1.blocks.0.sw_layer.layernorm_after.bias        |     96     |
# |         encoder.stages.1.blocks.0.sw_layer.mlp.dense1.weight         |   36,864   |
# |          encoder.stages.1.blocks.0.sw_layer.mlp.dense1.bias          |    384     |
# |         encoder.stages.1.blocks.0.sw_layer.mlp.dense2.weight         |   36,864   |
# |          encoder.stages.1.blocks.0.sw_layer.mlp.dense2.bias          |     96     |
# |           encoder.stages.1.patch_merging.layer_norm.weight           |    768     |
# |            encoder.stages.1.patch_merging.layer_norm.bias            |    768     |
# |              encoder.stages.1.patch_merging.proj.weight              |  147,456   |
# |               encoder.stages.1.patch_merging.proj.bias               |    192     |
# |      encoder.stages.2.blocks.0.w_layer.layernorm_before.weight       |    192     |
# |       encoder.stages.2.blocks.0.w_layer.layernorm_before.bias        |    192     |
# |          encoder.stages.2.blocks.0.w_layer.mhsa.W_q.weight           |   36,864   |
# |           encoder.stages.2.blocks.0.w_layer.mhsa.W_q.bias            |    192     |
# |          encoder.stages.2.blocks.0.w_layer.mhsa.W_k.weight           |   36,864   |
# |           encoder.stages.2.blocks.0.w_layer.mhsa.W_k.bias            |    192     |
# |          encoder.stages.2.blocks.0.w_layer.mhsa.W_v.weight           |   36,864   |
# |           encoder.stages.2.blocks.0.w_layer.mhsa.W_v.bias            |    192     |
# |          encoder.stages.2.blocks.0.w_layer.mhsa.proj.weight          |   36,864   |
# |           encoder.stages.2.blocks.0.w_layer.mhsa.proj.bias           |    192     |
# |       encoder.stages.2.blocks.0.w_layer.layernorm_after.weight       |    192     |
# |        encoder.stages.2.blocks.0.w_layer.layernorm_after.bias        |    192     |
# |         encoder.stages.2.blocks.0.w_layer.mlp.dense1.weight          |  147,456   |
# |          encoder.stages.2.blocks.0.w_layer.mlp.dense1.bias           |    768     |
# |         encoder.stages.2.blocks.0.w_layer.mlp.dense2.weight          |  147,456   |
# |          encoder.stages.2.blocks.0.w_layer.mlp.dense2.bias           |    192     |
# |      encoder.stages.2.blocks.0.sw_layer.layernorm_before.weight      |    192     |
# |       encoder.stages.2.blocks.0.sw_layer.layernorm_before.bias       |    192     |
# |          encoder.stages.2.blocks.0.sw_layer.mhsa.W_q.weight          |   36,864   |
# |           encoder.stages.2.blocks.0.sw_layer.mhsa.W_q.bias           |    192     |
# |          encoder.stages.2.blocks.0.sw_layer.mhsa.W_k.weight          |   36,864   |
# |           encoder.stages.2.blocks.0.sw_layer.mhsa.W_k.bias           |    192     |
# |          encoder.stages.2.blocks.0.sw_layer.mhsa.W_v.weight          |   36,864   |
# |           encoder.stages.2.blocks.0.sw_layer.mhsa.W_v.bias           |    192     |
# |         encoder.stages.2.blocks.0.sw_layer.mhsa.proj.weight          |   36,864   |
# |          encoder.stages.2.blocks.0.sw_layer.mhsa.proj.bias           |    192     |
# |      encoder.stages.2.blocks.0.sw_layer.layernorm_after.weight       |    192     |
# |       encoder.stages.2.blocks.0.sw_layer.layernorm_after.bias        |    192     |
# |         encoder.stages.2.blocks.0.sw_layer.mlp.dense1.weight         |  147,456   |
# |          encoder.stages.2.blocks.0.sw_layer.mlp.dense1.bias          |    768     |
# |         encoder.stages.2.blocks.0.sw_layer.mlp.dense2.weight         |  147,456   |
# |          encoder.stages.2.blocks.0.sw_layer.mlp.dense2.bias          |    192     |
# |      encoder.stages.2.blocks.1.w_layer.layernorm_before.weight       |    192     |
# |       encoder.stages.2.blocks.1.w_layer.layernorm_before.bias        |    192     |
# |          encoder.stages.2.blocks.1.w_layer.mhsa.W_q.weight           |   36,864   |
# |           encoder.stages.2.blocks.1.w_layer.mhsa.W_q.bias            |    192     |
# |          encoder.stages.2.blocks.1.w_layer.mhsa.W_k.weight           |   36,864   |
# |           encoder.stages.2.blocks.1.w_layer.mhsa.W_k.bias            |    192     |
# |          encoder.stages.2.blocks.1.w_layer.mhsa.W_v.weight           |   36,864   |
# |           encoder.stages.2.blocks.1.w_layer.mhsa.W_v.bias            |    192     |
# |          encoder.stages.2.blocks.1.w_layer.mhsa.proj.weight          |   36,864   |
# |           encoder.stages.2.blocks.1.w_layer.mhsa.proj.bias           |    192     |
# |       encoder.stages.2.blocks.1.w_layer.layernorm_after.weight       |    192     |
# |        encoder.stages.2.blocks.1.w_layer.layernorm_after.bias        |    192     |
# |         encoder.stages.2.blocks.1.w_layer.mlp.dense1.weight          |  147,456   |
# |          encoder.stages.2.blocks.1.w_layer.mlp.dense1.bias           |    768     |
# |         encoder.stages.2.blocks.1.w_layer.mlp.dense2.weight          |  147,456   |
# |          encoder.stages.2.blocks.1.w_layer.mlp.dense2.bias           |    192     |
# |      encoder.stages.2.blocks.1.sw_layer.layernorm_before.weight      |    192     |
# |       encoder.stages.2.blocks.1.sw_layer.layernorm_before.bias       |    192     |
# |          encoder.stages.2.blocks.1.sw_layer.mhsa.W_q.weight          |   36,864   |
# |           encoder.stages.2.blocks.1.sw_layer.mhsa.W_q.bias           |    192     |
# |          encoder.stages.2.blocks.1.sw_layer.mhsa.W_k.weight          |   36,864   |
# |           encoder.stages.2.blocks.1.sw_layer.mhsa.W_k.bias           |    192     |
# |          encoder.stages.2.blocks.1.sw_layer.mhsa.W_v.weight          |   36,864   |
# |           encoder.stages.2.blocks.1.sw_layer.mhsa.W_v.bias           |    192     |
# |         encoder.stages.2.blocks.1.sw_layer.mhsa.proj.weight          |   36,864   |
# |          encoder.stages.2.blocks.1.sw_layer.mhsa.proj.bias           |    192     |
# |      encoder.stages.2.blocks.1.sw_layer.layernorm_after.weight       |    192     |
# |       encoder.stages.2.blocks.1.sw_layer.layernorm_after.bias        |    192     |
# |         encoder.stages.2.blocks.1.sw_layer.mlp.dense1.weight         |  147,456   |
# |          encoder.stages.2.blocks.1.sw_layer.mlp.dense1.bias          |    768     |
# |         encoder.stages.2.blocks.1.sw_layer.mlp.dense2.weight         |  147,456   |
# |          encoder.stages.2.blocks.1.sw_layer.mlp.dense2.bias          |    192     |
# |      encoder.stages.2.blocks.2.w_layer.layernorm_before.weight       |    192     |
# |       encoder.stages.2.blocks.2.w_layer.layernorm_before.bias        |    192     |
# |          encoder.stages.2.blocks.2.w_layer.mhsa.W_q.weight           |   36,864   |
# |           encoder.stages.2.blocks.2.w_layer.mhsa.W_q.bias            |    192     |
# |          encoder.stages.2.blocks.2.w_layer.mhsa.W_k.weight           |   36,864   |
# |           encoder.stages.2.blocks.2.w_layer.mhsa.W_k.bias            |    192     |
# |          encoder.stages.2.blocks.2.w_layer.mhsa.W_v.weight           |   36,864   |
# |           encoder.stages.2.blocks.2.w_layer.mhsa.W_v.bias            |    192     |
# |          encoder.stages.2.blocks.2.w_layer.mhsa.proj.weight          |   36,864   |
# |           encoder.stages.2.blocks.2.w_layer.mhsa.proj.bias           |    192     |
# |       encoder.stages.2.blocks.2.w_layer.layernorm_after.weight       |    192     |
# |        encoder.stages.2.blocks.2.w_layer.layernorm_after.bias        |    192     |
# |         encoder.stages.2.blocks.2.w_layer.mlp.dense1.weight          |  147,456   |
# |          encoder.stages.2.blocks.2.w_layer.mlp.dense1.bias           |    768     |
# |         encoder.stages.2.blocks.2.w_layer.mlp.dense2.weight          |  147,456   |
# |          encoder.stages.2.blocks.2.w_layer.mlp.dense2.bias           |    192     |
# |      encoder.stages.2.blocks.2.sw_layer.layernorm_before.weight      |    192     |
# |       encoder.stages.2.blocks.2.sw_layer.layernorm_before.bias       |    192     |
# |          encoder.stages.2.blocks.2.sw_layer.mhsa.W_q.weight          |   36,864   |
# |           encoder.stages.2.blocks.2.sw_layer.mhsa.W_q.bias           |    192     |
# |          encoder.stages.2.blocks.2.sw_layer.mhsa.W_k.weight          |   36,864   |
# |           encoder.stages.2.blocks.2.sw_layer.mhsa.W_k.bias           |    192     |
# |          encoder.stages.2.blocks.2.sw_layer.mhsa.W_v.weight          |   36,864   |
# |           encoder.stages.2.blocks.2.sw_layer.mhsa.W_v.bias           |    192     |
# |         encoder.stages.2.blocks.2.sw_layer.mhsa.proj.weight          |   36,864   |
# |          encoder.stages.2.blocks.2.sw_layer.mhsa.proj.bias           |    192     |
# |      encoder.stages.2.blocks.2.sw_layer.layernorm_after.weight       |    192     |
# |       encoder.stages.2.blocks.2.sw_layer.layernorm_after.bias        |    192     |
# |         encoder.stages.2.blocks.2.sw_layer.mlp.dense1.weight         |  147,456   |
# |          encoder.stages.2.blocks.2.sw_layer.mlp.dense1.bias          |    768     |
# |         encoder.stages.2.blocks.2.sw_layer.mlp.dense2.weight         |  147,456   |
# |          encoder.stages.2.blocks.2.sw_layer.mlp.dense2.bias          |    192     |
# |           encoder.stages.2.patch_merging.layer_norm.weight           |   1,536    |
# |            encoder.stages.2.patch_merging.layer_norm.bias            |   1,536    |
# |              encoder.stages.2.patch_merging.proj.weight              |  589,824   |
# |               encoder.stages.2.patch_merging.proj.bias               |    384     |
# |      encoder.stages.3.blocks.0.w_layer.layernorm_before.weight       |    384     |
# |       encoder.stages.3.blocks.0.w_layer.layernorm_before.bias        |    384     |
# | encoder.stages.3.blocks.0.w_layer.mhsa.relative_position_bias_table  |   1,372    |
# |          encoder.stages.3.blocks.0.w_layer.mhsa.W_q.weight           |  147,456   |
# |           encoder.stages.3.blocks.0.w_layer.mhsa.W_q.bias            |    384     |
# |          encoder.stages.3.blocks.0.w_layer.mhsa.W_k.weight           |  147,456   |
# |           encoder.stages.3.blocks.0.w_layer.mhsa.W_k.bias            |    384     |
# |          encoder.stages.3.blocks.0.w_layer.mhsa.W_v.weight           |  147,456   |
# |           encoder.stages.3.blocks.0.w_layer.mhsa.W_v.bias            |    384     |
# |          encoder.stages.3.blocks.0.w_layer.mhsa.proj.weight          |  147,456   |
# |           encoder.stages.3.blocks.0.w_layer.mhsa.proj.bias           |    384     |
# |       encoder.stages.3.blocks.0.w_layer.layernorm_after.weight       |    384     |
# |        encoder.stages.3.blocks.0.w_layer.layernorm_after.bias        |    384     |
# |         encoder.stages.3.blocks.0.w_layer.mlp.dense1.weight          |  589,824   |
# |          encoder.stages.3.blocks.0.w_layer.mlp.dense1.bias           |   1,536    |
# |         encoder.stages.3.blocks.0.w_layer.mlp.dense2.weight          |  589,824   |
# |          encoder.stages.3.blocks.0.w_layer.mlp.dense2.bias           |    384     |
# |      encoder.stages.3.blocks.0.sw_layer.layernorm_before.weight      |    384     |
# |       encoder.stages.3.blocks.0.sw_layer.layernorm_before.bias       |    384     |
# | encoder.stages.3.blocks.0.sw_layer.mhsa.relative_position_bias_table |   1,372    |
# |          encoder.stages.3.blocks.0.sw_layer.mhsa.W_q.weight          |  147,456   |
# |           encoder.stages.3.blocks.0.sw_layer.mhsa.W_q.bias           |    384     |
# |          encoder.stages.3.blocks.0.sw_layer.mhsa.W_k.weight          |  147,456   |
# |           encoder.stages.3.blocks.0.sw_layer.mhsa.W_k.bias           |    384     |
# |          encoder.stages.3.blocks.0.sw_layer.mhsa.W_v.weight          |  147,456   |
# |           encoder.stages.3.blocks.0.sw_layer.mhsa.W_v.bias           |    384     |
# |         encoder.stages.3.blocks.0.sw_layer.mhsa.proj.weight          |  147,456   |
# |          encoder.stages.3.blocks.0.sw_layer.mhsa.proj.bias           |    384     |
# |      encoder.stages.3.blocks.0.sw_layer.layernorm_after.weight       |    384     |
# |       encoder.stages.3.blocks.0.sw_layer.layernorm_after.bias        |    384     |
# |         encoder.stages.3.blocks.0.sw_layer.mlp.dense1.weight         |  589,824   |
# |          encoder.stages.3.blocks.0.sw_layer.mlp.dense1.bias          |   1,536    |
# |         encoder.stages.3.blocks.0.sw_layer.mlp.dense2.weight         |  589,824   |
# |          encoder.stages.3.blocks.0.sw_layer.mlp.dense2.bias          |    384     |
# +----------------------------------------------------------------------+------------+

# %% [markdown]
# ### Overfitting tests

# %%
from tqdm.auto import tqdm

sample_spacings = torch.tensor([[1, 0.1, 0.1], [2, 0.2, 0.2], [3, 0.3, 0.3], [4, 0.4, 0.4], [5, 0.5, 0.5]])
sample_batch = torch.rand(3, 1, 16, 128, 128)
sample_config = {
    "patch_size": (1, 4, 4),
    "in_channels": 1,
    "use_absolute_position_embeddings": True,
    "learnable_absolute_position_embeddings": False,
    "embed_spacing_info": False,
    "image_size": (16, 128, 128),
    "stages": [],
    "mim": {
        "mask_ratio": 0.7,
        "mask_grid_size": (8, 8, 8),
    },
}
sample_config["stages"].append(
    {
        "depth": 1,
        "dim": 12,
        "num_heads": 4,
        "intermediate_ratio": 4,
        "layer_norm_eps": 1e-6,
        "window_size": (4, 4, 4),
        "use_relative_position_bias": True,
        "patch_merging": {
            "merge_window_size": (2, 2, 2),
            "out_dim_ratio": 4,
        },
    }
)
sample_config["stages"].append(
    {
        "depth": 3,
        "dim": sample_config["stages"][-1]["dim"] * sample_config["stages"][-1]["patch_merging"]["out_dim_ratio"],
        "num_heads": 4,
        "intermediate_ratio": 4,
        "layer_norm_eps": 1e-6,
        "window_size": (4, 4, 4),
        "use_relative_position_bias": True,
        "patch_merging": {
            "merge_window_size": (2, 2, 2),
            "out_dim_ratio": 4,
        },
    }
)
sample_config["stages"].append(
    {
        "depth": 1,
        "dim": sample_config["stages"][-1]["dim"] * sample_config["stages"][-1]["patch_merging"]["out_dim_ratio"],
        "num_heads": 4,
        "intermediate_ratio": 4,
        "layer_norm_eps": 1e-6,
        "window_size": (4, 4, 4),
        "use_relative_position_bias": True,
        "patch_merging": None,
    }
)

model = Swin3DMIM(sample_config)

sum(x.numel() for x in model.swin.parameters()), sum(x.numel() for x in model.decoder.parameters())
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# (1156612, 197632)

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=0.5)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.9)

# %%
sample_batch = sample_batch.cuda()
sample_spacings = sample_spacings.cuda()
model = model.cuda()

# %%
for i in tqdm(range(200)):
    optimizer.zero_grad()
    output = model(sample_batch, sample_spacings)
    print(f"Loss: {output[1]:f}\tLR: {scheduler.get_last_lr()[0]:f}")
    output[1].backward()
    optimizer.step()
    scheduler.step()
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Loss: 1.820429	LR: 0.500000
# Loss: 1.987945	LR: 0.500000
# Loss: 1.967435	LR: 0.500000
# Loss: 2.308640	LR: 0.500000
# Loss: 2.168925	LR: 0.500000
# Loss: 2.207896	LR: 0.450000
# Loss: 2.152745	LR: 0.450000
# Loss: 2.326722	LR: 0.450000
# Loss: 2.213367	LR: 0.450000
# Loss: 2.072788	LR: 0.450000
# Loss: 2.212431	LR: 0.405000
# Loss: 2.075707	LR: 0.405000
# Loss: 2.134526	LR: 0.405000
# Loss: 2.043120	LR: 0.405000
# Loss: 1.940446	LR: 0.405000
# Loss: 1.967878	LR: 0.364500
# Loss: 1.656061	LR: 0.364500
# Loss: 1.712492	LR: 0.364500
# Loss: 1.583969	LR: 0.364500
# Loss: 1.320167	LR: 0.364500
# Loss: 1.395069	LR: 0.328050
# Loss: 1.224852	LR: 0.328050
# Loss: 1.678762	LR: 0.328050
# Loss: 1.253203	LR: 0.328050
# Loss: 1.520050	LR: 0.328050
# Loss: 1.030859	LR: 0.295245
# Loss: 1.008602	LR: 0.295245
# Loss: 1.087134	LR: 0.295245
# Loss: 1.035728	LR: 0.295245
# Loss: 1.025624	LR: 0.295245
# Loss: 1.029193	LR: 0.265721
# Loss: 0.838549	LR: 0.265721
# Loss: 0.813711	LR: 0.265721
# Loss: 0.810683	LR: 0.265721
# Loss: 0.822165	LR: 0.265721
# Loss: 0.841314	LR: 0.239148
# Loss: 0.828372	LR: 0.239148
# Loss: 0.797421	LR: 0.239148
# Loss: 0.788176	LR: 0.239148
# Loss: 0.786287	LR: 0.239148
# Loss: 0.791746	LR: 0.215234
# Loss: 0.791189	LR: 0.215234
# Loss: 0.794116	LR: 0.215234
# Loss: 0.792036	LR: 0.215234
# Loss: 0.794098	LR: 0.215234
# Loss: 0.790384	LR: 0.193710
# Loss: 0.781108	LR: 0.193710
# Loss: 0.774374	LR: 0.193710
# Loss: 0.771430	LR: 0.193710
# Loss: 0.769585	LR: 0.193710
# Loss: 0.767889	LR: 0.174339
# Loss: 0.765394	LR: 0.174339
# Loss: 0.763916	LR: 0.174339
# Loss: 0.762770	LR: 0.174339
# Loss: 0.761887	LR: 0.174339
# Loss: 0.761124	LR: 0.156905
# Loss: 0.760942	LR: 0.156905
# Loss: 0.760127	LR: 0.156905
# Loss: 0.759776	LR: 0.156905
# Loss: 0.759333	LR: 0.156905
# Loss: 0.759376	LR: 0.141215
# Loss: 0.758985	LR: 0.141215
# Loss: 0.758578	LR: 0.141215
# Loss: 0.757882	LR: 0.141215
# Loss: 0.758446	LR: 0.141215
# Loss: 0.757533	LR: 0.127093
# Loss: 0.757631	LR: 0.127093
# Loss: 0.757413	LR: 0.127093
# Loss: 0.757111	LR: 0.127093
# Loss: 0.757267	LR: 0.127093
# Loss: 0.757034	LR: 0.114384
# Loss: 0.756936	LR: 0.114384
# Loss: 0.756795	LR: 0.114384
# Loss: 0.756579	LR: 0.114384
# Loss: 0.756543	LR: 0.114384
# Loss: 0.756151	LR: 0.102946
# Loss: 0.756308	LR: 0.102946
# Loss: 0.756139	LR: 0.102946
# Loss: 0.755795	LR: 0.102946
# Loss: 0.755578	LR: 0.102946
# Loss: 0.755576	LR: 0.092651
# Loss: 0.756137	LR: 0.092651
# Loss: 0.755511	LR: 0.092651
# Loss: 0.755358	LR: 0.092651
# Loss: 0.755680	LR: 0.092651
# Loss: 0.755317	LR: 0.083386
# Loss: 0.755556	LR: 0.083386
# Loss: 0.755649	LR: 0.083386
# Loss: 0.755429	LR: 0.083386
# Loss: 0.754922	LR: 0.083386
# Loss: 0.754681	LR: 0.075047
# Loss: 0.755137	LR: 0.075047
# Loss: 0.754723	LR: 0.075047
# Loss: 0.755061	LR: 0.075047
# Loss: 0.754688	LR: 0.075047
# Loss: 0.754518	LR: 0.067543
# Loss: 0.754637	LR: 0.067543
# Loss: 0.754434	LR: 0.067543
# Loss: 0.754796	LR: 0.067543
# Loss: 0.754481	LR: 0.067543
# Loss: 0.754269	LR: 0.060788
# Loss: 0.754253	LR: 0.060788
# Loss: 0.754536	LR: 0.060788
# Loss: 0.754338	LR: 0.060788
# Loss: 0.754174	LR: 0.060788
# Loss: 0.754129	LR: 0.054709
# Loss: 0.754486	LR: 0.054709
# Loss: 0.754278	LR: 0.054709
# Loss: 0.753979	LR: 0.054709
# Loss: 0.754307	LR: 0.054709
# Loss: 0.754082	LR: 0.049239
# Loss: 0.754087	LR: 0.049239
# Loss: 0.754100	LR: 0.049239
# Loss: 0.754102	LR: 0.049239
# Loss: 0.754532	LR: 0.049239
# Loss: 0.753786	LR: 0.044315
# Loss: 0.754009	LR: 0.044315
# Loss: 0.754024	LR: 0.044315
# Loss: 0.753612	LR: 0.044315
# Loss: 0.753886	LR: 0.044315
# Loss: 0.753905	LR: 0.039883
# Loss: 0.753452	LR: 0.039883
# Loss: 0.753929	LR: 0.039883
# Loss: 0.753808	LR: 0.039883
# Loss: 0.753386	LR: 0.039883
# Loss: 0.754135	LR: 0.035895
# Loss: 0.754217	LR: 0.035895
# Loss: 0.753820	LR: 0.035895
# Loss: 0.753723	LR: 0.035895
# Loss: 0.753675	LR: 0.035895
# Loss: 0.753270	LR: 0.032305
# Loss: 0.753520	LR: 0.032305
# Loss: 0.753470	LR: 0.032305
# Loss: 0.753492	LR: 0.032305
# Loss: 0.753569	LR: 0.032305
# Loss: 0.753262	LR: 0.029075
# Loss: 0.753439	LR: 0.029075
# Loss: 0.753796	LR: 0.029075
# Loss: 0.753688	LR: 0.029075
# Loss: 0.753756	LR: 0.029075
# Loss: 0.753508	LR: 0.026167
# Loss: 0.753169	LR: 0.026167
# Loss: 0.753403	LR: 0.026167
# Loss: 0.753591	LR: 0.026167
# Loss: 0.753504	LR: 0.026167
# Loss: 0.753204	LR: 0.023551
# Loss: 0.753237	LR: 0.023551
# Loss: 0.753252	LR: 0.023551
# Loss: 0.753431	LR: 0.023551
# Loss: 0.753303	LR: 0.023551
# Loss: 0.753233	LR: 0.021196
# Loss: 0.753291	LR: 0.021196
# Loss: 0.753575	LR: 0.021196
# Loss: 0.753388	LR: 0.021196
# Loss: 0.753111	LR: 0.021196
# Loss: 0.753417	LR: 0.019076
# Loss: 0.753166	LR: 0.019076
# Loss: 0.753564	LR: 0.019076
# Loss: 0.753552	LR: 0.019076
# Loss: 0.752976	LR: 0.019076
# Loss: 0.753294	LR: 0.017168
# Loss: 0.753206	LR: 0.017168
# Loss: 0.753626	LR: 0.017168
# Loss: 0.753330	LR: 0.017168
# Loss: 0.753409	LR: 0.017168
# Loss: 0.753314	LR: 0.015452
# Loss: 0.753145	LR: 0.015452
# Loss: 0.753183	LR: 0.015452
# Loss: 0.753235	LR: 0.015452
# Loss: 0.753234	LR: 0.015452
# Loss: 0.753128	LR: 0.013906
# Loss: 0.752938	LR: 0.013906
# Loss: 0.753255	LR: 0.013906
# Loss: 0.753329	LR: 0.013906
# Loss: 0.753236	LR: 0.013906
# Loss: 0.752777	LR: 0.012516
# Loss: 0.753188	LR: 0.012516
# Loss: 0.753227	LR: 0.012516
# Loss: 0.753373	LR: 0.012516
# Loss: 0.753271	LR: 0.012516
# Loss: 0.753419	LR: 0.011264
# Loss: 0.753169	LR: 0.011264
# Loss: 0.753358	LR: 0.011264
# Loss: 0.753365	LR: 0.011264
# Loss: 0.753273	LR: 0.011264
# Loss: 0.753455	LR: 0.010138
# Loss: 0.753072	LR: 0.010138
# Loss: 0.753188	LR: 0.010138
# Loss: 0.753183	LR: 0.010138
# Loss: 0.752654	LR: 0.010138
# Loss: 0.752821	LR: 0.009124
# Loss: 0.753295	LR: 0.009124
# Loss: 0.752819	LR: 0.009124
# Loss: 0.753049	LR: 0.009124
# Loss: 0.752590	LR: 0.009124
# Loss: 0.753239	LR: 0.008212
# Loss: 0.753089	LR: 0.008212
# Loss: 0.752912	LR: 0.008212
# Loss: 0.753214	LR: 0.008212
# Loss: 0.753195	LR: 0.008212

# %% [markdown]
# # Migration from old to new

# %%
# | export


def migrate_checkpoint_to_new(checkpoint, prefix="model"):
    model_config = checkpoint["hyper_parameters"]["model_config"]

    model_config["dim"] = model_config["stages"][0]["dim"]
    for stage in model_config["stages"]:
        del stage["dim"]

    for i in range(len(model_config["stages"]) - 1, 0, -1):
        model_config["stages"][i]["patch_merging"] = model_config["stages"][i - 1]["patch_merging"]
    model_config["stages"][0]["patch_merging"] = None

    checkpoint["hyper_parameters"]["model_config"] = populate_and_validate_config(
        checkpoint["hyper_parameters"]["model_config"]
    )

    state_dict = checkpoint["state_dict"]

    for stage_i in range(len(model_config["stages"])):
        for block_i in range(model_config["stages"][stage_i]["depth"]):
            for layer_name in {"w_layer", "sw_layer"}:
                for state_type in {"weight", "bias"}:
                    q = state_dict.pop(
                        f"{prefix}.swin.encoder.stages.{stage_i}.blocks.{block_i}.{layer_name}.mhsa.W_q.{state_type}"
                    )
                    k = state_dict.pop(
                        f"{prefix}.swin.encoder.stages.{stage_i}.blocks.{block_i}.{layer_name}.mhsa.W_k.{state_type}"
                    )
                    v = state_dict.pop(
                        f"{prefix}.swin.encoder.stages.{stage_i}.blocks.{block_i}.{layer_name}.mhsa.W_v.{state_type}"
                    )
                    qkv = torch.concat([q, k, v], dim=0)
                    state_dict[
                        f"{prefix}.swin.encoder.stages.{stage_i}.blocks.{block_i}.{layer_name}.mhsa.W_qkv.{state_type}"
                    ] = qkv

    for i in range(len(model_config["stages"]) - 1, 0, -1):
        state_dict[f"{prefix}.swin.encoder.stages.{i}.patch_merging.layer_norm.weight"] = state_dict.pop(
            f"{prefix}.swin.encoder.stages.{i-1}.patch_merging.layer_norm.weight"
        )
        state_dict[f"{prefix}.swin.encoder.stages.{i}.patch_merging.layer_norm.bias"] = state_dict.pop(
            f"{prefix}.swin.encoder.stages.{i-1}.patch_merging.layer_norm.bias"
        )
        state_dict[f"{prefix}.swin.encoder.stages.{i}.patch_merging.proj.weight"] = state_dict.pop(
            f"{prefix}.swin.encoder.stages.{i-1}.patch_merging.proj.weight"
        )
        state_dict[f"{prefix}.swin.encoder.stages.{i}.patch_merging.proj.bias"] = state_dict.pop(
            f"{prefix}.swin.encoder.stages.{i-1}.patch_merging.proj.bias"
        )

    return checkpoint

# %%
old = torch.load(
    r"/cache/expdata1/arjun/checkpoints/ct_pretraining/v11__2024_04_19/version_0/checkpoints/epoch=16.ckpt",
    map_location="cpu",
)

new = migrate_checkpoint_to_new(old)

display(new["hyper_parameters"]["model_config"].toDict())
model = Swin3DNewMIM(new["hyper_parameters"]["model_config"])

state_dict = new["state_dict"]
for k in state_dict.copy():
    state_dict[k.removeprefix("model.")] = state_dict.pop(k)

model.load_state_dict(state_dict)
describe_model(model)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {
#     'patch_size': (1, 4, 4),
#     'in_channels': 1,
#     'use_absolute_position_embeddings': True,
#     'learnable_absolute_position_embeddings': False,
#     'embed_spacing_info': False,
#     'image_size': (32, 256, 256),
#     'stages': [
#         {
#             'depth': 1,
#             'num_heads': 4,
#             'intermediate_ratio': 4,
#             'layer_norm_eps': 1e-06,
#             'window_size': (4, 4, 4),
#             'use_relative_position_bias': True,
#             'patch_merging': None,
#             '_in_dim': 12,
#             '_in_patch_size': (1, 4, 4),
#             '_out_dim': 12,
#             '_out_patch_size': (1, 4, 4)
#         },
#         {
#             'depth': 1,
#             'num_heads': 4,
#             'intermediate_ratio': 4,
#             'layer_norm_eps': 1e-06,
#             'window_size': (4, 4, 4),
#             'use_relative_position_bias': True,
#             'patch_merging': {'merge_window_size': (2, 2, 2), 'out_dim_ratio': 4},
#             '_in_dim': 12,
#             '_in_patch_size': (1, 4, 4),
#             '_out_dim': 48,
#             '_out_patch_size': (2, 8, 8)
#         },
#         {
#             'depth': 3,
#             'num_heads': 4,
#             'intermediate_ratio': 4,
#             'layer_norm_eps': 1e-06,
#             'window_size': (4, 4, 4),
#             'use_relative_position_bias': True,
#             'patch_merging': {'merge_window_size': (2, 2, 2), 'out_dim_ratio': 4},
#             '_in_dim': 48,
#             '_in_patch_size': (2, 8, 8),
#             '_out_dim': 192,
#             '_out_patch_size': (4, 16, 16)
#         },
#         {
#             'depth': 1,
#             'num_heads': 4,
#             'intermediate_ratio': 4,
#             'layer_norm_eps': 1e-06,
#             'window_size': (4, 4, 4),
#             'use_relative_position_bias': True,
#             'patch_merging': {'merge_window_size': (2, 2, 2), 'out_dim_ratio': 4},
#             '_in_dim': 192,
#             '_in_patch_size': (4, 16, 16),
#             '_out_dim': 768,
#             '_out_patch_size': (8, 32, 32)
#         }
#     ],
#     'mim': {'mask_ratio': 0.8, 'mask_grid_size': (16, 16, 16)},
#     'dim': 12
# }
# Total Parameters: 24,484,616
# +---------------------------------------------------------------------------+------------+
# |                                   Module                                  | Parameters |
# +---------------------------------------------------------------------------+------------+
# |                                 mask_token                                |     12     |
# |          swin.embeddings.patch_embeddings.patch_embeddings.weight         |    192     |
# |           swin.embeddings.patch_embeddings.patch_embeddings.bias          |     12     |
# |                     swin.embeddings.layer_norm.weight                     |     12     |
# |                      swin.embeddings.layer_norm.bias                      |     12     |
# |       swin.encoder.stages.0.blocks.0.w_layer.layernorm_before.weight      |     12     |
# |        swin.encoder.stages.0.blocks.0.w_layer.layernorm_before.bias       |     12     |
# |  swin.encoder.stages.0.blocks.0.w_layer.mhsa.relative_position_bias_table |   1,372    |
# |          swin.encoder.stages.0.blocks.0.w_layer.mhsa.W_qkv.weight         |    432     |
# |           swin.encoder.stages.0.blocks.0.w_layer.mhsa.W_qkv.bias          |     36     |
# |          swin.encoder.stages.0.blocks.0.w_layer.mhsa.proj.weight          |    144     |
# |           swin.encoder.stages.0.blocks.0.w_layer.mhsa.proj.bias           |     12     |
# |       swin.encoder.stages.0.blocks.0.w_layer.layernorm_after.weight       |     12     |
# |        swin.encoder.stages.0.blocks.0.w_layer.layernorm_after.bias        |     12     |
# |          swin.encoder.stages.0.blocks.0.w_layer.mlp.dense1.weight         |    576     |
# |           swin.encoder.stages.0.blocks.0.w_layer.mlp.dense1.bias          |     48     |
# |          swin.encoder.stages.0.blocks.0.w_layer.mlp.dense2.weight         |    576     |
# |           swin.encoder.stages.0.blocks.0.w_layer.mlp.dense2.bias          |     12     |
# |      swin.encoder.stages.0.blocks.0.sw_layer.layernorm_before.weight      |     12     |
# |       swin.encoder.stages.0.blocks.0.sw_layer.layernorm_before.bias       |     12     |
# | swin.encoder.stages.0.blocks.0.sw_layer.mhsa.relative_position_bias_table |   1,372    |
# |         swin.encoder.stages.0.blocks.0.sw_layer.mhsa.W_qkv.weight         |    432     |
# |          swin.encoder.stages.0.blocks.0.sw_layer.mhsa.W_qkv.bias          |     36     |
# |          swin.encoder.stages.0.blocks.0.sw_layer.mhsa.proj.weight         |    144     |
# |           swin.encoder.stages.0.blocks.0.sw_layer.mhsa.proj.bias          |     12     |
# |       swin.encoder.stages.0.blocks.0.sw_layer.layernorm_after.weight      |     12     |
# |        swin.encoder.stages.0.blocks.0.sw_layer.layernorm_after.bias       |     12     |
# |         swin.encoder.stages.0.blocks.0.sw_layer.mlp.dense1.weight         |    576     |
# |          swin.encoder.stages.0.blocks.0.sw_layer.mlp.dense1.bias          |     48     |
# |         swin.encoder.stages.0.blocks.0.sw_layer.mlp.dense2.weight         |    576     |
# |          swin.encoder.stages.0.blocks.0.sw_layer.mlp.dense2.bias          |     12     |
# |           swin.encoder.stages.1.patch_merging.layer_norm.weight           |     96     |
# |            swin.encoder.stages.1.patch_merging.layer_norm.bias            |     96     |
# |              swin.encoder.stages.1.patch_merging.proj.weight              |   4,608    |
# |               swin.encoder.stages.1.patch_merging.proj.bias               |     48     |
# |       swin.encoder.stages.1.blocks.0.w_layer.layernorm_before.weight      |     48     |
# |        swin.encoder.stages.1.blocks.0.w_layer.layernorm_before.bias       |     48     |
# |  swin.encoder.stages.1.blocks.0.w_layer.mhsa.relative_position_bias_table |   1,372    |
# |          swin.encoder.stages.1.blocks.0.w_layer.mhsa.W_qkv.weight         |   6,912    |
# |           swin.encoder.stages.1.blocks.0.w_layer.mhsa.W_qkv.bias          |    144     |
# |          swin.encoder.stages.1.blocks.0.w_layer.mhsa.proj.weight          |   2,304    |
# |           swin.encoder.stages.1.blocks.0.w_layer.mhsa.proj.bias           |     48     |
# |       swin.encoder.stages.1.blocks.0.w_layer.layernorm_after.weight       |     48     |
# |        swin.encoder.stages.1.blocks.0.w_layer.layernorm_after.bias        |     48     |
# |          swin.encoder.stages.1.blocks.0.w_layer.mlp.dense1.weight         |   9,216    |
# |           swin.encoder.stages.1.blocks.0.w_layer.mlp.dense1.bias          |    192     |
# |          swin.encoder.stages.1.blocks.0.w_layer.mlp.dense2.weight         |   9,216    |
# |           swin.encoder.stages.1.blocks.0.w_layer.mlp.dense2.bias          |     48     |
# |      swin.encoder.stages.1.blocks.0.sw_layer.layernorm_before.weight      |     48     |
# |       swin.encoder.stages.1.blocks.0.sw_layer.layernorm_before.bias       |     48     |
# | swin.encoder.stages.1.blocks.0.sw_layer.mhsa.relative_position_bias_table |   1,372    |
# |         swin.encoder.stages.1.blocks.0.sw_layer.mhsa.W_qkv.weight         |   6,912    |
# |          swin.encoder.stages.1.blocks.0.sw_layer.mhsa.W_qkv.bias          |    144     |
# |          swin.encoder.stages.1.blocks.0.sw_layer.mhsa.proj.weight         |   2,304    |
# |           swin.encoder.stages.1.blocks.0.sw_layer.mhsa.proj.bias          |     48     |
# |       swin.encoder.stages.1.blocks.0.sw_layer.layernorm_after.weight      |     48     |
# |        swin.encoder.stages.1.blocks.0.sw_layer.layernorm_after.bias       |     48     |
# |         swin.encoder.stages.1.blocks.0.sw_layer.mlp.dense1.weight         |   9,216    |
# |          swin.encoder.stages.1.blocks.0.sw_layer.mlp.dense1.bias          |    192     |
# |         swin.encoder.stages.1.blocks.0.sw_layer.mlp.dense2.weight         |   9,216    |
# |          swin.encoder.stages.1.blocks.0.sw_layer.mlp.dense2.bias          |     48     |
# |           swin.encoder.stages.2.patch_merging.layer_norm.weight           |    384     |
# |            swin.encoder.stages.2.patch_merging.layer_norm.bias            |    384     |
# |              swin.encoder.stages.2.patch_merging.proj.weight              |   73,728   |
# |               swin.encoder.stages.2.patch_merging.proj.bias               |    192     |
# |       swin.encoder.stages.2.blocks.0.w_layer.layernorm_before.weight      |    192     |
# |        swin.encoder.stages.2.blocks.0.w_layer.layernorm_before.bias       |    192     |
# |  swin.encoder.stages.2.blocks.0.w_layer.mhsa.relative_position_bias_table |   1,372    |
# |          swin.encoder.stages.2.blocks.0.w_layer.mhsa.W_qkv.weight         |  110,592   |
# |           swin.encoder.stages.2.blocks.0.w_layer.mhsa.W_qkv.bias          |    576     |
# |          swin.encoder.stages.2.blocks.0.w_layer.mhsa.proj.weight          |   36,864   |
# |           swin.encoder.stages.2.blocks.0.w_layer.mhsa.proj.bias           |    192     |
# |       swin.encoder.stages.2.blocks.0.w_layer.layernorm_after.weight       |    192     |
# |        swin.encoder.stages.2.blocks.0.w_layer.layernorm_after.bias        |    192     |
# |          swin.encoder.stages.2.blocks.0.w_layer.mlp.dense1.weight         |  147,456   |
# |           swin.encoder.stages.2.blocks.0.w_layer.mlp.dense1.bias          |    768     |
# |          swin.encoder.stages.2.blocks.0.w_layer.mlp.dense2.weight         |  147,456   |
# |           swin.encoder.stages.2.blocks.0.w_layer.mlp.dense2.bias          |    192     |
# |      swin.encoder.stages.2.blocks.0.sw_layer.layernorm_before.weight      |    192     |
# |       swin.encoder.stages.2.blocks.0.sw_layer.layernorm_before.bias       |    192     |
# | swin.encoder.stages.2.blocks.0.sw_layer.mhsa.relative_position_bias_table |   1,372    |
# |         swin.encoder.stages.2.blocks.0.sw_layer.mhsa.W_qkv.weight         |  110,592   |
# |          swin.encoder.stages.2.blocks.0.sw_layer.mhsa.W_qkv.bias          |    576     |
# |          swin.encoder.stages.2.blocks.0.sw_layer.mhsa.proj.weight         |   36,864   |
# |           swin.encoder.stages.2.blocks.0.sw_layer.mhsa.proj.bias          |    192     |
# |       swin.encoder.stages.2.blocks.0.sw_layer.layernorm_after.weight      |    192     |
# |        swin.encoder.stages.2.blocks.0.sw_layer.layernorm_after.bias       |    192     |
# |         swin.encoder.stages.2.blocks.0.sw_layer.mlp.dense1.weight         |  147,456   |
# |          swin.encoder.stages.2.blocks.0.sw_layer.mlp.dense1.bias          |    768     |
# |         swin.encoder.stages.2.blocks.0.sw_layer.mlp.dense2.weight         |  147,456   |
# |          swin.encoder.stages.2.blocks.0.sw_layer.mlp.dense2.bias          |    192     |
# |       swin.encoder.stages.2.blocks.1.w_layer.layernorm_before.weight      |    192     |
# |        swin.encoder.stages.2.blocks.1.w_layer.layernorm_before.bias       |    192     |
# |  swin.encoder.stages.2.blocks.1.w_layer.mhsa.relative_position_bias_table |   1,372    |
# |          swin.encoder.stages.2.blocks.1.w_layer.mhsa.W_qkv.weight         |  110,592   |
# |           swin.encoder.stages.2.blocks.1.w_layer.mhsa.W_qkv.bias          |    576     |
# |          swin.encoder.stages.2.blocks.1.w_layer.mhsa.proj.weight          |   36,864   |
# |           swin.encoder.stages.2.blocks.1.w_layer.mhsa.proj.bias           |    192     |
# |       swin.encoder.stages.2.blocks.1.w_layer.layernorm_after.weight       |    192     |
# |        swin.encoder.stages.2.blocks.1.w_layer.layernorm_after.bias        |    192     |
# |          swin.encoder.stages.2.blocks.1.w_layer.mlp.dense1.weight         |  147,456   |
# |           swin.encoder.stages.2.blocks.1.w_layer.mlp.dense1.bias          |    768     |
# |          swin.encoder.stages.2.blocks.1.w_layer.mlp.dense2.weight         |  147,456   |
# |           swin.encoder.stages.2.blocks.1.w_layer.mlp.dense2.bias          |    192     |
# |      swin.encoder.stages.2.blocks.1.sw_layer.layernorm_before.weight      |    192     |
# |       swin.encoder.stages.2.blocks.1.sw_layer.layernorm_before.bias       |    192     |
# | swin.encoder.stages.2.blocks.1.sw_layer.mhsa.relative_position_bias_table |   1,372    |
# |         swin.encoder.stages.2.blocks.1.sw_layer.mhsa.W_qkv.weight         |  110,592   |
# |          swin.encoder.stages.2.blocks.1.sw_layer.mhsa.W_qkv.bias          |    576     |
# |          swin.encoder.stages.2.blocks.1.sw_layer.mhsa.proj.weight         |   36,864   |
# |           swin.encoder.stages.2.blocks.1.sw_layer.mhsa.proj.bias          |    192     |
# |       swin.encoder.stages.2.blocks.1.sw_layer.layernorm_after.weight      |    192     |
# |        swin.encoder.stages.2.blocks.1.sw_layer.layernorm_after.bias       |    192     |
# |         swin.encoder.stages.2.blocks.1.sw_layer.mlp.dense1.weight         |  147,456   |
# |          swin.encoder.stages.2.blocks.1.sw_layer.mlp.dense1.bias          |    768     |
# |         swin.encoder.stages.2.blocks.1.sw_layer.mlp.dense2.weight         |  147,456   |
# |          swin.encoder.stages.2.blocks.1.sw_layer.mlp.dense2.bias          |    192     |
# |       swin.encoder.stages.2.blocks.2.w_layer.layernorm_before.weight      |    192     |
# |        swin.encoder.stages.2.blocks.2.w_layer.layernorm_before.bias       |    192     |
# |  swin.encoder.stages.2.blocks.2.w_layer.mhsa.relative_position_bias_table |   1,372    |
# |          swin.encoder.stages.2.blocks.2.w_layer.mhsa.W_qkv.weight         |  110,592   |
# |           swin.encoder.stages.2.blocks.2.w_layer.mhsa.W_qkv.bias          |    576     |
# |          swin.encoder.stages.2.blocks.2.w_layer.mhsa.proj.weight          |   36,864   |
# |           swin.encoder.stages.2.blocks.2.w_layer.mhsa.proj.bias           |    192     |
# |       swin.encoder.stages.2.blocks.2.w_layer.layernorm_after.weight       |    192     |
# |        swin.encoder.stages.2.blocks.2.w_layer.layernorm_after.bias        |    192     |
# |          swin.encoder.stages.2.blocks.2.w_layer.mlp.dense1.weight         |  147,456   |
# |           swin.encoder.stages.2.blocks.2.w_layer.mlp.dense1.bias          |    768     |
# |          swin.encoder.stages.2.blocks.2.w_layer.mlp.dense2.weight         |  147,456   |
# |           swin.encoder.stages.2.blocks.2.w_layer.mlp.dense2.bias          |    192     |
# |      swin.encoder.stages.2.blocks.2.sw_layer.layernorm_before.weight      |    192     |
# |       swin.encoder.stages.2.blocks.2.sw_layer.layernorm_before.bias       |    192     |
# | swin.encoder.stages.2.blocks.2.sw_layer.mhsa.relative_position_bias_table |   1,372    |
# |         swin.encoder.stages.2.blocks.2.sw_layer.mhsa.W_qkv.weight         |  110,592   |
# |          swin.encoder.stages.2.blocks.2.sw_layer.mhsa.W_qkv.bias          |    576     |
# |          swin.encoder.stages.2.blocks.2.sw_layer.mhsa.proj.weight         |   36,864   |
# |           swin.encoder.stages.2.blocks.2.sw_layer.mhsa.proj.bias          |    192     |
# |       swin.encoder.stages.2.blocks.2.sw_layer.layernorm_after.weight      |    192     |
# |        swin.encoder.stages.2.blocks.2.sw_layer.layernorm_after.bias       |    192     |
# |         swin.encoder.stages.2.blocks.2.sw_layer.mlp.dense1.weight         |  147,456   |
# |          swin.encoder.stages.2.blocks.2.sw_layer.mlp.dense1.bias          |    768     |
# |         swin.encoder.stages.2.blocks.2.sw_layer.mlp.dense2.weight         |  147,456   |
# |          swin.encoder.stages.2.blocks.2.sw_layer.mlp.dense2.bias          |    192     |
# |           swin.encoder.stages.3.patch_merging.layer_norm.weight           |   1,536    |
# |            swin.encoder.stages.3.patch_merging.layer_norm.bias            |   1,536    |
# |              swin.encoder.stages.3.patch_merging.proj.weight              | 1,179,648  |
# |               swin.encoder.stages.3.patch_merging.proj.bias               |    768     |
# |       swin.encoder.stages.3.blocks.0.w_layer.layernorm_before.weight      |    768     |
# |        swin.encoder.stages.3.blocks.0.w_layer.layernorm_before.bias       |    768     |
# |  swin.encoder.stages.3.blocks.0.w_layer.mhsa.relative_position_bias_table |   1,372    |
# |          swin.encoder.stages.3.blocks.0.w_layer.mhsa.W_qkv.weight         | 1,769,472  |
# |           swin.encoder.stages.3.blocks.0.w_layer.mhsa.W_qkv.bias          |   2,304    |
# |          swin.encoder.stages.3.blocks.0.w_layer.mhsa.proj.weight          |  589,824   |
# |           swin.encoder.stages.3.blocks.0.w_layer.mhsa.proj.bias           |    768     |
# |       swin.encoder.stages.3.blocks.0.w_layer.layernorm_after.weight       |    768     |
# |        swin.encoder.stages.3.blocks.0.w_layer.layernorm_after.bias        |    768     |
# |          swin.encoder.stages.3.blocks.0.w_layer.mlp.dense1.weight         | 2,359,296  |
# |           swin.encoder.stages.3.blocks.0.w_layer.mlp.dense1.bias          |   3,072    |
# |          swin.encoder.stages.3.blocks.0.w_layer.mlp.dense2.weight         | 2,359,296  |
# |           swin.encoder.stages.3.blocks.0.w_layer.mlp.dense2.bias          |    768     |
# |      swin.encoder.stages.3.blocks.0.sw_layer.layernorm_before.weight      |    768     |
# |       swin.encoder.stages.3.blocks.0.sw_layer.layernorm_before.bias       |    768     |
# | swin.encoder.stages.3.blocks.0.sw_layer.mhsa.relative_position_bias_table |   1,372    |
# |         swin.encoder.stages.3.blocks.0.sw_layer.mhsa.W_qkv.weight         | 1,769,472  |
# |          swin.encoder.stages.3.blocks.0.sw_layer.mhsa.W_qkv.bias          |   2,304    |
# |          swin.encoder.stages.3.blocks.0.sw_layer.mhsa.proj.weight         |  589,824   |
# |           swin.encoder.stages.3.blocks.0.sw_layer.mhsa.proj.bias          |    768     |
# |       swin.encoder.stages.3.blocks.0.sw_layer.layernorm_after.weight      |    768     |
# |        swin.encoder.stages.3.blocks.0.sw_layer.layernorm_after.bias       |    768     |
# |         swin.encoder.stages.3.blocks.0.sw_layer.mlp.dense1.weight         | 2,359,296  |
# |          swin.encoder.stages.3.blocks.0.sw_layer.mlp.dense1.bias          |   3,072    |
# |         swin.encoder.stages.3.blocks.0.sw_layer.mlp.dense2.weight         | 2,359,296  |
# |          swin.encoder.stages.3.blocks.0.sw_layer.mlp.dense2.bias          |    768     |
# |                           decoder.decoder.weight                          | 6,291,456  |
# |                            decoder.decoder.bias                           |   8,192    |
# +---------------------------------------------------------------------------+------------+

# %% [markdown]
# # nbdev

# %%
# !nbdev_export

# %% [markdown]
# # Rough work

# %% [raw]
# coords_h = torch.arange(4)
# coords_w = torch.arange(4)
# coords = torch.stack(torch.meshgrid([coords_h, coords_w], indexing="ij"))
# coords_flatten = torch.flatten(coords, 1)
# relative_coords = coords_flatten[:, :, None] - coords_flatten[:, None, :]
# relative_coords = relative_coords.permute(1, 2, 0).contiguous()
# relative_coords[:, :, 0] += 4 - 1
# relative_coords[:, :, 1] += 4 - 1
# relative_coords[:, :, 0] *= 2 * 4 - 1
# relative_position_index = relative_coords.sum(-1)
#
# relative_position_index.min(), relative_position_index.max()

# %% [raw]
# window_size = (4, 4, 4)
# relative_limits = (7, 7, 7)
#
# coords = get_coords_grid(window_size)
# coords_flatten = rearrange(coords, "three_dimensional d h w -> three_dimensional (d h w)", three_dimensional=3)
# relative_coords = coords_flatten[:, :, None] - coords_flatten[:, None, :]
# relative_coords = relative_coords.permute(1, 2, 0).contiguous()
# relative_coords[:, :, 0] += window_size[0] - 1
# relative_coords[:, :, 1] += window_size[1] - 1
# relative_coords[:, :, 2] += window_size[2] - 1
# relative_position_index: torch.Tensor = (
#     relative_coords[:, :, 0] * relative_limits[1] * relative_limits[2]
#     + relative_coords[:, :, 1] * relative_limits[2]
#     + relative_coords[:, :, 2]
# )
#
# relative_position_index.min(), relative_position_index.max()
